# %%
---
layout: post
title: Astro Platgame
courses: csse
codemirror: true
permalink: /astroplatgame/
author: Jasan, Krish, Aarnav
mermaid: false
---

# %% [markdown]
# <style>
# .astro-fullscreen-wrap {
#   width: 100vw;
#   height: calc(100vh - 56px);
#   margin-left: calc(50% - 50vw);
#   margin-right: calc(50% - 50vw);
#   background: #000;
#   overflow: hidden;
# }
#
# #astro-fullscreen-game {
#   width: 100%;
#   height: 100%;
# }
# </style>
#
# <div class="astro-fullscreen-wrap">
#   <div id="astro-fullscreen-game"></div>
# </div>
#
# <script type="module">
# const base = '{{ site.baseurl }}';
#
# import Game from '{{ site.baseurl }}/assets/js/GameEnginev1.1/essentials/Game.js';
# import { GameControl } from '{{ site.baseurl }}/assets/js/GameEnginev1.1/essentials/Imports.js';
# import AstroStory from '{{ site.baseurl }}/assets/js/projects/astronaut-platformer-game/levels/astrostory.js';
# import AstroMeteor from '{{ site.baseurl }}/assets/js/projects/astronaut-platformer-game/levels/astrometeor.js';
# import AstroMaze from '{{ site.baseurl }}/assets/js/projects/astronaut-platformer-game/levels/astromaze.js';
# import AstroPlatformer from '{{ site.baseurl }}/assets/js/projects/astronaut-platformer-game/levels/astroplatformer.js';
# import AstroDeath from '{{ site.baseurl }}/assets/js/projects/astronaut-platformer-game/levels/astrodeath.js';
# import AstroMusic from '{{ site.baseurl }}/assets/js/projects/astronaut-platformer-game/levels/astromusic.js';
#
# const astroMusicApi = new AstroMusic();
# astroMusicApi.addGestureListeners();
#
# const gameContainer = document.getElementById('astro-fullscreen-game');
# const gameLevelClasses = [AstroStory, AstroMeteor, AstroMaze, AstroPlatformer, AstroDeath];
#
# function mountGame() {
#   const innerWidth = gameContainer.clientWidth || window.innerWidth;
#   const innerHeight = gameContainer.clientHeight || Math.max(window.innerHeight - 56, 520);
#
#   const environment = {
#     path: base,
#     gameContainer,
#     gameLevelClasses,
#     innerWidth,
#     innerHeight,
#     disablePauseMenu: false,
#     disableContainerAdjustment: true,
#   };
#
#   if (window.__astroGame?.destroy) {
#     try {
#       window.__astroGame.destroy();
#     } catch (_) {
#       // Ignore cleanup failures and remount fresh.
#     }
#   }
#
#   window.__astroGame = Game.main(environment, GameControl);
# }
#
# mountGame();
# window.addEventListener('resize', () => {
#   clearTimeout(window.__astroResizeTimer);
#   window.__astroResizeTimer = setTimeout(mountGame, 150);
# });
# </script>
