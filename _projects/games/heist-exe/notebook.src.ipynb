# %% [markdown]
# ---
# layout: post
# title: Collision Mechanics
# description: Learn how collision mechanics work and how to use it.
# permalink: /heist-exe
# author: Vihaan Budhraja, Rigved Reddy Gaddam, Seonyoo Pak, Rishab Shyamal
# ---

# %%
# %%js
#
# import GameControl from '@assets/js/GameEnginev1.1/essentials/GameControl.js';
# import HeistTemplate from '@assets/js/projects/heist-exe/levels/HeistTemplate.js';
# import HeistL2 from '@assets/js/projects/heist-exe/levels/HeistL2.js';
# // GAME_RUNNER: CSSE Zone Game | hide_edit: true,  width: 100%, height: 500px
#
# export const gameLevelClasses = [HeistTemplate, HeistL2];
# export { GameControl };
