# %% [markdown]
# ---
# layout: post
# title: Level 1 Mummy
# description: Mummy resurrection level
# permalink: /mummy
# hide: false
# toc: false
# author: Rashi, Samaghna, Anika, Aashi, Rohit
# codemirror: true
# microblog: true
# ---
