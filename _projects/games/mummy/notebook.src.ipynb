# %% [markdown]
# ---
# layout: post
# title: Level 1 Mummy
# description: Mummy resurrection level
# permalink: /mummy
# hide: false
# toc: false
# author: Rashi, Samaghna, Anika, Aashi, Rohit
# codemirror: true
# microblog: true
# ---

# %%
# %%js
# // GAME_RUNNER: CSSE Zone Game | hide_edit: true, width: 100%, height: 580px
#
# import GameControl from '/assets/js/GameEnginev1.1/essentials/GameControl.js';
# import GameLevelMummy1 from '/assets/js/projects/mummy/levels/level1.js';
#
# export { GameControl };
# export const gameLevelClasses = [GameLevelMummy1];
