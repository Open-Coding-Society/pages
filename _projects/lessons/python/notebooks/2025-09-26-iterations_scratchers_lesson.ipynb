# %% [raw]
# ---
# layout: post
# categories: [Python, Iterations]
# lesson_language: Python
# lesson_topic: Iterations
# lesson_part: interactive
# lesson_type: lesson
# codemirror: true
# microblog: true
# toc: false
# comments: false
# title: Iterations in Python
# description: Learn Python iteration with hands-on loop examples, control flow, and code runner challenges.
# permalink: /python/iterations
# ---

# %% [raw]
# <div id="python-runner-scratchers-fallback-marker" style="display:none">Python browser fallback installed</div>
# <script>
# (function () {
#   if (window.__pythonIterationsScratchersFallbackInstalled) return;
#   window.__pythonIterationsScratchersFallbackInstalled = true;
#
#   const originalFetch = window.fetch.bind(window);
#   let pyodidePromise = null;
#
#   function loadPyodideRuntime() {
#     if (pyodidePromise) return pyodidePromise;
#
#     pyodidePromise = new Promise((resolve, reject) => {
#       function startPyodide() {
#         if (!window.loadPyodide) {
#           reject(new Error('Pyodide loader was not found'));
#           return;
#         }
#         resolve(window.loadPyodide({
#           indexURL: 'https://cdn.jsdelivr.net/pyodide/v0.26.4/full/'
#         }));
#       }
#
#       if (window.loadPyodide) {
#         startPyodide();
#         return;
#       }
#
#       const script = document.createElement('script');
#       script.src = 'https://cdn.jsdelivr.net/pyodide/v0.26.4/full/pyodide.js';
#       script.async = true;
#       script.onload = startPyodide;
#       script.onerror = () => reject(new Error('Pyodide failed to load'));
#       document.head.appendChild(script);
#     });
#
#     return pyodidePromise;
#   }
#
#   async function runPythonInBrowser(code) {
#     const pyodide = await loadPyodideRuntime();
#     const output = [];
#
#     if (typeof pyodide.setStdout === 'function') {
#       pyodide.setStdout({ batched: (text) => output.push(text) });
#     }
#     if (typeof pyodide.setStderr === 'function') {
#       pyodide.setStderr({ batched: (text) => output.push(text) });
#     }
#
#     await pyodide.runPythonAsync(code);
#     return output.length ? output.join(String.fromCharCode(10)) : '[no output]';
#   }
#
#   window.fetch = async function (input, init) {
#     const url = typeof input === 'string' ? input : (input && input.url) || '';
#     const method = (init && init.method ? init.method : 'GET').toUpperCase();
#     const isPythonRunner = url.includes('/run/python') && method === 'POST';
#
#     if (!isPythonRunner) {
#       return originalFetch(input, init);
#     }
#
#     try {
#       return await originalFetch(input, init);
#     } catch (error) {
#       let code = '';
#       try {
#         code = JSON.parse((init && init.body) || '{}').code || '';
#       } catch (parseError) {
#         throw error;
#       }
#
#       if (!code) throw error;
#
#       const output = await runPythonInBrowser(code);
#       return new Response(JSON.stringify({ output }), {
#         status: 200,
#         headers: { 'Content-Type': 'application/json' }
#       });
#     }
#   };
# })();
# </script>

# %% [markdown]
# # Iterations in Python
#
# Iteration means repeating a set of steps. In Python, loops help us process lists, check conditions, and stop when a goal has been reached.
#
# In this lesson, the examples use a realistic data-checking theme so the code connects to everyday programming: a tool can scan values, ignore safe ones, and act when a threshold is reached.

# %% [markdown]
# ## The Big Idea
#
# Loops let a program repeat work without copying the same instructions over and over.
#
# You will practice four core ideas:
#
# - `for` loops repeat through a known sequence, such as a list of readings.
# - `while` loops repeat until a condition changes.
# - `break` stops a loop early when the program has found what it needs.
# - `continue` skips the current item and keeps checking the rest.
#
# These patterns are useful in any project that needs to scan information, filter results, or respond to changing conditions.

# %% [markdown]
# ## Scenario
#
# Imagine a monitoring system needs a simple tool that reviews sensor data. The program might check readings, skip safe values, count active alerts, and stop when it finds a high-priority issue.
#
# That is exactly what iteration is for:
#
# - A `for` loop checks each item in a list.
# - A `while` loop keeps working until the situation becomes safe.
# - `continue` skips information that does not need action.
# - `break` stops once the highest-priority problem is found.
#
# Run each example, then connect the output back to the decision the program is making.

# %%
# CODE_RUNNER: Use a for loop to inspect a list of sensor readings.
readings = [34, 42, 31, 48, 29, 37]

for reading in readings:
  print(f"Checking reading: {reading}")
  if reading >= 40:
    print("High alert: investigate this reading.")
  else:
    print("Reading is within the normal range.")

# %% [markdown]
# ## `for` Loops: Inspect Each Item
#
# A `for` loop is best when you already have a collection to examine. The loop runs once for each item, using the same logic every time.
#
# ```python
# for value in [30, 42, 18, 55]:
#   print(f"Checking {value}...")
# ```
#
# The loop variable changes on each pass, so one block of code can inspect many different values.

# %%
# CODE_RUNNER: Keep checking until the temperature drops below 30.
temperature = 85
cooldown_count = 0

while temperature > 30:
  temperature -= 15
  cooldown_count += 1
  print(f"Cooling down... temperature is now {temperature}.")

print(f"Stabilized after {cooldown_count} cooling cycles.")

# %% [markdown]
# ## `while` Loops: Repeat Until Safe
#
# A `while` loop keeps running as long as its condition is true. This is useful when you do not know exactly how many repetitions will be needed.
#
# ```python
# temperature = 85
# cooldown_count = 0
#
# while temperature > 30:
#   temperature -= 15
#   cooldown_count += 1
#   print(f"Cooling down... temperature is now {temperature}.")
#
# print(f"Stabilized after {cooldown_count} cooling cycles.")
# ```
#
# The important rule: make sure something inside the loop eventually changes the condition. Otherwise, the loop can run forever.

# %%
# CODE_RUNNER: SRFSC should skip safe zones and stop once the severe fire is found.
fire_levels = [7, 4, 2, 9, 1]

for level in fire_levels:
  if level <= 2:
    print(f"Zone is stable: {level}")
    continue
  print(f"Crew responds to level {level}")
  if level >= 8:
    print("Severe fire detected — focus on the main fire line.")
    break

# %% [markdown]
# ## `break` and `continue`
#
# Loop-control statements help a program make better decisions while it repeats.
#
# - `continue` skips the rest of the current loop pass and moves to the next item.
# - `break` exits the loop completely.
#
# In the SRFSC example, safe zones can be skipped, while a severe fire should stop the scan and become the top priority.
#
# ```python
# fire_levels = [7, 4, 2, 9, 1]
# for level in fire_levels:
#   if level <= 2:
#     print(f"Zone is stable: {level}")
#     continue
#   print(f"Crew responds to level {level}")
#   if level >= 8:
#     print("Severe fire detected — focus on the main fire line.")
#     break
# ```

# %% [markdown]
# ## Quick Challenge
#
# Before you run the next example, predict the output.
#
# A fire crew checks several alert readings. If a reading is `3` or higher, the zone is still active. If it is below `3`, the zone is stable.
#
# Use the loop below to count how many fire zones are still active.

# %%
# CODE_RUNNER: SRFSC needs one final count. Count the fire zones that are still active and print the total.
alerts = [3, 2, 5, 1, 8, 4, 0]
active_zones = 0

for alert in alerts:
  if alert >= 3:
    active_zones += 1
    print(f"Alert at {alert}: fire still active")
  else:
    print(f"Alert at {alert}: zone is stable")

print(f"Total active fire zones: {active_zones}")

# %% [markdown]
# ## Lesson Flow
#
# This lesson is designed as a short interactive activity.
#
# | Time | Activity | Goal |
# | --- | --- | --- |
# | 1-2 minutes | Quick teach | Explain how loops repeat work and support decision-making. |
# | 5 minutes per person | Interactive practice | Run, trace, and explain the Python examples. |
# | 10 minutes | Extra work | Build a small loop-based checker of your own. |
# | End | Submit | Turn in your notebook for review. |
#
# As you work, focus on both the code and the reason behind it: what is the loop checking, when should it skip, and when should it stop?

# %% [markdown]
# ## Learning Experience Design (LxD) Process
#
# This lesson follows an evidence-based LxD sequence to maximize learning and transfer.
#
# - **Activate prior knowledge:** quick prediction tasks before running code.
# - **Demonstrate:** short worked examples to show loop behavior (`for`/`while`/`break`/`continue`).
# - **Practice:** Popcorn Hacks — micro-tasks students complete and run immediately.
# - **Reflect:** short written reflection questions in the notebook after code cells.
# - **Apply:** homework that requires integrating the patterns into a small project.
#
# Use the sections below to follow this flow during class time.

# %% [markdown]
# ## Lesson Plan (Teacher-facing)
#
# | Time | Activity | Learning Goal |
# | --- | --- | --- |
# | 1–2 min | Hook: ask students to predict loop output for a short snippet | Activate prior knowledge and set expectations |
# | 5 min | Demonstration: run the `for` example and trace output together | Model tracing and variable changes |
# | 10–15 min | Popcorn Hacks (paired) | Guided practice with immediate feedback |
# | 8–10 min | Reflection & share | Students articulate why loops printed certain values |
# | 8–12 min | Apply/Homework assignment | Create a loop-based checker in portfolio |
#
# **Notes:** keep examples short and code-first; use the `# CODE_RUNNER:` cells so students can run locally or via the runner.

# %% [markdown]
# ## Rubric (Quick, 1-point scale — align to standards)
#
# | Criteria | 0.0 | 0.5 | 1.0 |
# | --- | ---: | ---: | ---: |
# | Predicts output | No attempt or incorrect | Partially correct | Fully correct with explanation |
# | Uses `continue` correctly | Incorrect or missing | Partially correct usage | Correct usage and explanation |
# | Uses `break` correctly | Incorrect or missing | Partial behavior | Correct behavior with summary |
# | Homework checker | Not implemented or fails | Runs but incomplete | Runs and meets all requirements |
#
# Scoring: sum the columns for a quick out-of-1 score (see Grading Checklist below).

# %% [markdown]
# ## Learning Targets
#
# By the end of this lesson, you should be able to:
#
# - Explain the difference between a `for` loop and a `while` loop.
# - Use a loop to process a list of values.
# - Use `continue` to skip values that do not need action.
# - Use `break` to stop once a key condition is found.
# - Trace loop output before running the code.
#
# Success looks like being able to explain not only what the loop prints, but why it prints that result.

# %% [markdown]
# ## Practice Tasks
#
# ### Practice 1: Predict the Output
#
# Before running the code, write the exact output you expect.
#
# ```python
# for value in [2, 4, 6, 8]:
#   print(value * 2)
# ```
#
# ### Practice 2: Explain the Loop
#
# This loop prints the even numbers from 0 to 10. Explain how `continue` changes the flow.
#
# ```python
# for number in range(0, 11):
#   if number % 2 == 1:
#     continue
#   print(number)
# ```
#
# ### Practice 3: Choose the Right Loop
#
# Choose `for` or `while` for each task and explain your choice.
#
# 1. Print the numbers 1 through 20.
# 2. Keep asking for a password until the correct one is entered.
# 3. Read every item in a list of quiz scores and compute the total.
#
# ### Practice 4: Trace `break` and `continue`
#
# ```python
# scores = [10, 15, 7, 20, 5, 25]
# for score in scores:
#   if score < 10:
#     continue
#   print(score)
#   if score >= 20:
#     break
# ```
#
# Explain what happens when the code reaches `7`, `20`, and `25`.

# %% [markdown]
# ## Grading Checklist
#
# | Requirement | Points | What earns credit |
# | --- | ---: | --- |
# | Predicts loop output | 0.2 | Gives the correct output and explains the loop order. |
# | Explains `continue` | 0.2 | Describes which values are skipped and why. |
# | Chooses loop types | 0.2 | Selects reasonable loop types and justifies each choice. |
# | Traces `break` behavior | 0.2 | Explains when the loop stops and what does not run. |
# | Completes homework checker | 0.2 | Builds a working loop-based checker with a final summary. |
# | **Total** | **1.0** | |

# %% [markdown]
# ## Submission and Homework
#
# ### Prepare Your Submission Notebook
#
# 1. Create a new notebook in your portfolio homework area.
# 2. Add a raw frontmatter cell at the top.
# 3. Include a code cell for each practice task and the final homework cell.
# 4. Keep the `# CODE_RUNNER:` comment as the first line of each CodeRunner cell.
#
# ```raw
# ---
# layout: post
# title: Iterations HW
# categories: [Python]
# lesson_language: Python
# lesson_topic: Iterations HW
# lesson_part: interactive
# lesson_type: lesson
# permalink: /python/iterations-hw
# author: githubID
# ---
# ```
#
# ### Homework: Build a Loop-Based Checker
#
# Write a Python program that:
#
# 1. Uses a list of at least 6 values.
# 2. Uses a `for` loop to check each value.
# 3. Uses `continue` to skip values below a cutoff.
# 4. Uses `break` once a critical value is found.
# 5. Prints a final summary with how many valid values were processed.
#
# Example idea:
#
# ```python
# # CODE_RUNNER: Homework - Build a loop-based checker
# scores = [12, 7, 18, 5, 25, 9, 30]
# cutoff = 10
# valid_count = 0
#
# for score in scores:
#   if score < cutoff:
#     continue
#   valid_count += 1
#   print(f"Score {score} is valid")
#   if score >= 25:
#     print("Critical score found.")
#     break
#
# print(f"Valid scores counted: {valid_count}")
# ```
#
# ### Submission Safety Rules
#
# > [!IMPORTANT]
# > Make sure every submitted code cell runs without errors. Keep the `# CODE_RUNNER:` comment at the top of each CodeRunner cell so the page can render the interactive runner correctly.
#
# ### Final Reflection
#
# Answer these questions under your code:
#
# 1. Why did you choose a `for` loop or a `while` loop?
# 2. What condition causes your loop to skip or stop?
# 3. How does your final summary prove the loop worked?

# %% [markdown]
# ## OCS Submission Check
#
# Before you turn this in, make sure your notebook includes all completed practice cells and the homework checker.
#
# <div class="ocs__links ocs__links--wide">
#   <a class="ocs__btn alert-green fill small" href="/python/iterations-hw">Open Homework Template</a>
#   <a class="ocs__btn alert-yellow fill small" href="/submission">Submit to OCS</a>
# </div>
#
# > Final reminder: every code cell in your submitted notebook should run cleanly, and each `# CODE_RUNNER:` cell should stay at the top of the code block.

# %% [markdown]
# ## `while` Loops in Python
#
# A `while` loop repeats until its condition becomes false. Keep examples in Python only for this lesson — no JavaScript snippets or site-specific Sass are included here.
#
# ```python
# count = 1
# while count <= 5:
#   print(count)
#   count += 1
# ```
#
# Looping over lists with indices (Python):
#
# ```python
# names = ['Anwita', 'Nicholas', 'Varada']
# i = 0
# while i < len(names):
#   print('Hello', names[i])
#   i += 1
# ```

# %%
# CODE_RUNNER: Popcorn Hack - Loop Practice
# Fill in the TODOs and run to test your understanding of loops and control flow.
numbers = [2, 5, 8, 1, 10, 3]
total = 0
count = 0

for n in numbers:
  # TODO: skip numbers less than 3
  if n < 3:
    continue
  # TODO: add remaining numbers to total and increment count
  total += n
  count += 1

print("Count:", count)
print("Total:", total)

# %% [markdown]
# ## Control flow inside loops: break and continue
#
# - `break` exits the entire loop immediately.
# - `continue` skips the rest of the current iteration and goes to the next one.
#
# Example: print numbers 1–6 but skip 3 and stop when you reach 5.

# %%
for n in range(1, 8): # numbers 1 to 8
    if n == 3: # when n is 3
        continue  # skip number 3
    if n == 6: # when n is 6
        break  # stop the whole loop at 6
    print(n) # what number is printed

# Output: 1
#         2
#         4
#         5

# %% [markdown]
# ### 4) `break` and `continue`
# Python:
# ```python
# for i in range(1, 6):
#     if i == 3:
#         continue  # skip the rest of this iteration
#     if i == 5:
#         break     # exit the loop early
#     print(i)
# ```
# JavaScript:
# ```javascript
# for (let i = 1; i <= 5; i++) {
#   if (i === 3) continue;
#   if (i === 5) break;
#   console.log(i);
# }
# ```

# %% [markdown]
# ## Iterations Game — Multiple Choice (JavaScript / Python)
# Choose a language, read the snippet, and pick the correct output or behavior. You will get immediate "Correct" or "Incorrect" feedback and an explanation.

# %% [raw]
# <div id="quiz">
#   <div style="margin-bottom:10px;color: white;font-weight:bold;">
#     <label><input type="radio" name="lang" value="js" checked> JavaScript</label>
#     <label style="margin-left:10px;color: white;font-weight:bold;"><input type="radio" name="lang" value="py"> Python</label>
#   </div>
#
#   <div id="card" style="border:1px solid #ccc;padding:12px;border-radius:6px;background: #bc7e7eff;">
#     <h3 id="qnum">Question 1</h3>
#     <pre id="code" style="background:#272822;color: #f8f8f2;padding:10px;border-radius:4px;overflow:auto;"></pre>
#     <div id="choices"></div>
#     <div style="margin-top:8px;">
#       <button id="submit">Submit</button>
#       <button id="next" style="margin-left:8px;">Next</button>
#       <button id="explain" style="margin-left:8px;">Show Explanation</button>
#     </div>
#     <p id="result" style="font-weight:bold;margin-top:8px;color:black"></p>
#     <div id="explainText" style="margin-top:6px;color:#333;"></div>
#   </div>
# </div>
#
# <style>
#   button {
#     background-color: #5e3434ff;
#     color: white;
#     border: none;
#     border-radius: 8px;
#     padding: 8px 16px;
#     font-size: 14px;
#     font-family: "Segoe UI", sans-serif;
#     cursor: pointer;
#     transition: background-color 0.2s ease, transform 0.1s ease;
#     margin-left: 8px;
#   }
#
#   button:first-child {
#     margin-left: 0;
#   }
#
#   button:hover {
#     background-color: #5e3434ff;
#     transform: translateY(-2px);
#   }
#
#   button:active {
#     transform: translateY(0);
#   }
# </style>
#
# <script>
# (function(){
#   const questions = [
#     {
#       codeJS: "for (let i = 0; i < 3; i++) {\n  console.log(i);\n}",
#       codePy: "for i in range(3):\n    print(i)",
#       choices: ["0 1 2", "1 2 3", "0 1 2 3", "Error"],
#       answer: 0,
#       explain: "Loops start at 0 and run while i < 3, producing 0,1,2."
#     },
#     {
#       codeJS: "let i = 0;\nwhile (i < 3) {\n  i += 2;\n  console.log(i);\n}",
#       codePy: "i = 0\nwhile i < 3:\n    i += 2\n    print(i)",
#       choices: ["0 2", "2 4", "2", "0 1 2"],
#       answer: 1,
#       explain: "Each loop iteration increases i by 2 then prints. Values printed: 2 then 4."
#     },
#     {
#       codeJS: "const arr = [1,2,3];\nfor (const x of arr) console.log(x * 2);",
#       codePy: "for x in [1,2,3]:\n    print(x * 2)",
#       choices: ["2 4 6", "1 2 3", "2,4,6,8", "Error"],
#       answer: 0,
#       explain: "Each element is multiplied by 2: 2,4,6."
#     },
#     {
#       codeJS: "for (let i=0;i<5;i++){\n  if (i===2) break;\n  console.log(i);\n}",
#       codePy: "for i in range(5):\n    if i == 2:\n        break\n    print(i)",
#       choices: ["0 1", "0 1 2", "2 3 4", "0 1 2 3 4"],
#       answer: 0,
#       explain: "break stops the loop when i equals 2, so only 0 and 1 are printed."
#     },
#     {
#       codeJS: "for (let i=0;i<4;i++){\n  if (i%2===0) continue;\n  console.log(i);\n}",
#       codePy: "for i in range(4):\n    if i % 2 == 0:\n        continue\n    print(i)",
#       choices: ["1 3", "0 2", "0 1 2 3", "0 1 3"],
#       answer: 0,
#       explain: "continue skips even i (0 and 2), so only odd values 1 and 3 are printed."
#     },
#     {
#       codeJS: "for (let i=0;i<5;i++){\n  if (i===3) break;\n  console.log(i);\n}",
#       codePy: "for i in range(5):\n    if i == 3:\n        break\n    print(i)",
#       choices: ["0 1 2", "0 1 2 3", "1 2 3", "0 1"],
#       answer: 0,
#       explain: "The loop stops completely when i reaches 3, so it prints 0, 1, 2."
#     },
#     {
#       codeJS: "for(let i=0;i<5;i++){\n  if(i%2!==0) continue;\n  console.log(i);\n}",
#       codePy: "for i in range(5):\n    if i % 2 != 0:\n        continue\n    print(i)",
#       choices: ["0 2 4", "1 3", "0 1 2 3 4", "2 4"],
#       answer: 0,
#       explain: "continue skips odd numbers, so only even numbers 0,2,4 are printed."
#     },
#     {
#       codeJS: "let sum = 0;\nfor(let i=1;i<=3;i++){\n  sum += i;\n}\nconsole.log(sum);",
#       codePy: "sum = 0\nfor i in range(1,4):\n    sum += i\nprint(sum)",
#       choices: ["6", "5", "3", "Error"],
#       answer: 0,
#       explain: "The loop adds 1+2+3 to sum, resulting in 6."
#     },
#     {
#       codeJS: "let i = 1;\nwhile(i < 10) {\n  i *= 2;\n}\nconsole.log(i);",
#       codePy: "i = 1\nwhile i < 10:\n    i *= 2\nprint(i)",
#       choices: ["16", "8", "10", "Error"],
#       answer: 0,
#       explain: "i doubles each loop: 1,2,4,8, then 16 which breaks the loop. Final i is 16."
#     },
#     {
#       codeJS: "const arr = [2,4,6];\nlet prod = 1;\nfor(const x of arr) {\n  prod *= x;\n}\nconsole.log(prod);",
#       codePy: "arr = [2,4,6]\nprod = 1\nfor x in arr:\n    prod *= x\nprint(prod)",
#       choices: ["48", "12", "24", "Error"],
#       answer: 0,
#       explain: "The loop multiplies all elements: 1*2=2, 2*4=8, 8*6=48."
#     },
#     {
#       codeJS: "for(let i=0;i<3;i++){\n  for(let j=0;j<2;j++){\n    console.log(i,j);\n  }\n}",
#       codePy: "for i in range(3):\n    for j in range(2):\n        print(i,j)",
#       choices: ["0 0,0 1,1 0,1 1,2 0,2 1", "0 0,1 0,2 0", "0 1,1 1,2 1", "Error"],
#       answer: 0,
#       explain: "Nested loops produce all combinations of i (0-2) and j (0-1)."
#     },
#     {
#       codeJS: "let count = 0;\nfor(let i=0;i<5;i++){\n  if(i%2===0) count++;\n}\nconsole.log(count);",
#       codePy: "count = 0\nfor i in range(5):\n    if i % 2 == 0:\n        count += 1\nprint(count)",
#       choices: ["3", "2", "5", "Error"],
#       answer: 0,
#       explain: "The loop counts even numbers (0,2,4), resulting in count=3."
#     },
#     {
#       codeJS: "let i=0;\nwhile(i<4){\n  i++;\n  if(i===2) continue;\n  console.log(i);\n}",
#       codePy: "i = 0\nwhile i < 4:\n    i += 1\n    if i == 2:\n        continue\n    print(i)",
#       choices: ["1 3 4", "1 2 3 4", "2 3 4", "Error"],
#       answer: 0,
#       explain: "The loop increments i then prints unless i is 2. So it prints 1,3,4."
#     },
#     {
#       codeJS: "let total = 0;\nfor(let i=1;i<=4;i++){\n  if(i===3) break;\n  total += i;\n}\nconsole.log(total);",
#       codePy: "total = 0\nfor i in range(1,5):\n    if i == 3:\n        break\n    total += i\nprint(total)",
#       choices: ["3", "6", "10", "Error"],
#       answer: 0,
#       explain: "The loop adds 1+2 then breaks before adding 3, so total=3."
#     },
#     {
#       codeJS: "const arr = [1,2,3,4];\nlet sum=0;\nfor(const x of arr){\n  if(x%2===0) continue;\n  sum+=x;\n}\nconsole.log(sum);",
#       codePy: "arr = [1,2,3,4]\nsum = 0\nfor x in arr:\n    if x % 2 == 0:\n        continue\n    sum += x\nprint(sum)",
#       choices: ["4", "10", "6", "Error"],
#       answer: 0,
#       explain: "The loop sums only odd numbers (1 and 3), resulting in sum=4."
#     }
#   ];
#
#   let idx = 0;
#   let selected = null;
#
#   const codeEl = document.getElementById('code');
#   const choicesEl = document.getElementById('choices');
#   const resultEl = document.getElementById('result');
#   const explainEl = document.getElementById('explainText');
#   const qnumEl = document.getElementById('qnum');
#
#   function getLang() {
#     return document.querySelector('input[name="lang"]:checked').value;
#   }
#
#   function render() {
#     const q = questions[idx];
#     qnumEl.textContent = "Question " + (idx+1);
#     const lang = getLang();
#     codeEl.textContent = (lang === 'js') ? q.codeJS : q.codePy;
#     // render choices
#     choicesEl.innerHTML = '';
#     q.choices.forEach((c, i) => {
#       const id = 'opt' + i;
#       const wrapper = document.createElement('div');
#       wrapper.style.marginTop = '6px';
#       wrapper.innerHTML = `<label><input type="radio" name="choice" value="${i}" id="${id}"> ${escapeHtml(c)}</label>`;
#       choicesEl.appendChild(wrapper);
#     });
#     resultEl.textContent = '';
#     explainEl.textContent = '';
#     selected = null;
#     document.querySelectorAll('input[name="choice"]').forEach(r => r.addEventListener('change', e=> selected = parseInt(e.target.value)));
#   }
#
#   function escapeHtml(s){ return s.replace(/&/g,'&amp;').replace(/</g,'&lt;').replace(/>/g,'&gt;'); }
#
#   document.getElementById('submit').addEventListener('click', ()=>{
#     if (selected === null) { resultEl.textContent = "Pick an answer first."; resultEl.style.color = "darkorange"; return; }
#     const q = questions[idx];
#     if (selected === q.answer) {
#       resultEl.textContent = "Correct";
#       resultEl.style.color = "green";
#     } else {
#       resultEl.textContent = "Incorrect";
#       resultEl.style.color = "red";
#     }
#   });
#
#   document.getElementById('next').addEventListener('click', ()=>{
#     idx = (idx + 1) % questions.length;
#     render();
#   });
#
#   document.getElementById('explain').addEventListener('click', ()=>{
#     explainEl.textContent = questions[idx].explain;
#   });
#
#   document.querySelectorAll('input[name="lang"]').forEach(r=> r.addEventListener('change', render));
#
#   // initial render
#   render();
# })();
# </script>

# %% [markdown]
# ## Check for Understanding
#
# **Question:** What will this code output?
# ```python
# for i in range(3):
#     print("hi")
# ```
#
# - A) `hi`
# - B) `hi hi`
# - C) `hi hi hi`
# - D) Nothing
#
# **Correct Answer:** C
