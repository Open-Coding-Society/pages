# %% [raw]
# ---
# layout: post
# title: Ocean Game Lesson
# description: this is a lesson about implementing enemies into games, and how to do that in certain ways.
# permalink: /ocean
# codemirror: true
# hide: true
# toc: false
# ---

# %%
# %%js
#
# // GAME_RUNNER: CSSE Zone Game | hide_edit: true,  width: 100%, height: 500px
#
# import GameControl from '/assets/js/GameEnginev1.1/essentials/GameControl.js';
# import GameLevelOcean from '/assets/js/projects/ocean/levels/GameLevelOcean.js';
#
# export const gameLevelClasses = [GameLevelOcean];
# export { GameControl };
