# %% [markdown]
# ---
# layout: post
# title: Ocean
# description: The bridge from Gamebuilder to code management.
# permalink: /ocean/enemy
# hide: true
# toc: false
# author: John Mortensen
# ---

# %% [markdown]
# # Ocean Game
# It works!
