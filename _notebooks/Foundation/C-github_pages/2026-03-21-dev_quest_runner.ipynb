# %% [markdown]
# ---
# layout: post
# codemirror: true
# title: Dev Quest Runner
# description: A gamified learning environment for teaching Make, Git merge conflicts, debugging, and file structure through interactive quests. Complete quests, earn points, level up.
# permalink: /tools/gamified
# ---

# %% [markdown]
# ## Dev Quest Runner
#
# A gamified series of coding challenges built on the GameEngine framework. Each quest teaches a core developer skill — file structure, Makefiles, merge conflicts, and debugging. Complete quests in order to unlock the next one, earn points, and level up.
#
# **How it works:**
# - Each quest is a standalone game level with its own objectives
# - Players interact with the game world to complete tasks
# - Points and XP are awarded on completion
# - Quests must be completed in order

# %% [markdown]
# ## Quest 1: File Structure 101
#
# > Learn how to navigate a project's directory structure. Walk through the game world and interact with files and folders to build a proper project layout.

# %%
# %%js
#
# // GAME_RUNNER: Quest 1 - File Structure 101. Navigate the world and interact with folders to build a proper project layout. Use WASD to move.
#
# import GameControl from '/assets/js/GameEnginev1/essentials/GameControl.js';
# import GameEnvBackground from '/assets/js/GameEnginev1/essentials/GameEnvBackground.js';
# import Player from '/assets/js/GameEnginev1/essentials/Player.js';
# import Npc from '/assets/js/GameEnginev1/essentials/Npc.js';
#
# class QuestFileStructure {
#   constructor(gameEnv) {
#     const path = gameEnv.path;
#     const width = gameEnv.innerWidth;
#     const height = gameEnv.innerHeight;
#
#     const bgData = {
#       name: 'quest1_bg',
#       src: path + '/images/gamify-tools/clouds.jpg',
#       pixels: { height: 720, width: 1280 }
#     };
#
#     const playerData = {
#       id: 'DevHero',
#       src: path + '/images/gamify-tools/chillguy.png',
#       SCALE_FACTOR: 5,
#       STEP_FACTOR: 1000,
#       ANIMATION_RATE: 50,
#       INIT_POSITION: { x: 50, y: height / 2 },
#       pixels: { height: 512, width: 384 },
#       orientation: { rows: 4, columns: 3 },
#       down: { row: 0, start: 0, columns: 3 },
#       downRight: { row: 1, start: 0, columns: 3, rotate: Math.PI / 16 },
#       downLeft: { row: 2, start: 0, columns: 3, rotate: -Math.PI / 16 },
#       right: { row: 1, start: 0, columns: 3 },
#       left: { row: 2, start: 0, columns: 3 },
#       up: { row: 3, start: 0, columns: 3 },
#       upRight: { row: 1, start: 0, columns: 3, rotate: -Math.PI / 16 },
#       upLeft: { row: 2, start: 0, columns: 3, rotate: Math.PI / 16 },
#       hitbox: { widthPercentage: 0.45, heightPercentage: 0.2 },
#       keypress: { up: 87, left: 65, down: 83, right: 68 }
#     };
#
#     // NPC representing the src/ folder
#     const srcFolderNpc = {
#       id: 'src_folder',
#       src: path + '/images/gamify-tools/robot.png',
#       SCALE_FACTOR: 5,
#       ANIMATION_RATE: 100,
#       INIT_POSITION: { x: width * 0.3, y: height / 2 },
#       pixels: { height: 256, width: 256 },
#       orientation: { rows: 1, columns: 1 },
#       down: { row: 0, start: 0, columns: 1 },
#       hitbox: { widthPercentage: 0.5, heightPercentage: 0.5 },
#       dialogues: [
#         'I am the src/ folder! Source code lives here.',
#         'Put your .js, .py, or .java files inside me.',
#         'Objective complete: src/ folder found! +50 pts'
#       ]
#     };
#
#     // NPC representing the README
#     const readmeNpc = {
#       id: 'readme_file',
#       src: path + '/images/gamify-tools/robot.png',
#       SCALE_FACTOR: 5,
#       ANIMATION_RATE: 100,
#       INIT_POSITION: { x: width * 0.6, y: height / 2 },
#       pixels: { height: 256, width: 256 },
#       orientation: { rows: 1, columns: 1 },
#       down: { row: 0, start: 0, columns: 1 },
#       hitbox: { widthPercentage: 0.5, heightPercentage: 0.5 },
#       dialogues: [
#         'I am README.md! Every project needs one.',
#         'Describe your project, how to install it, and how to run it.',
#         'Objective complete: README.md found! +50 pts'
#       ]
#     };
#
#     this.classes = [
#       { class: GameEnvBackground, data: bgData },
#       { class: Player, data: playerData },
#       { class: Npc, data: srcFolderNpc },
#       { class: Npc, data: readmeNpc },
#     ];
#   }
# }
#
# export const gameLevelClasses = [QuestFileStructure];
# export { GameControl };

# %% [markdown]
# ## Quest 2: Make It Build
#
# > Learn how Makefiles automate builds. Find the Makefile NPC and unlock the build and clean targets.

# %%
# %%js
#
# // GAME_RUNNER: Quest 2 - Make It Build. Find the Makefile and learn how build automation works. Use WASD to move, interact with NPCs to learn.
#
# import GameControl from '/assets/js/GameEnginev1/essentials/GameControl.js';
# import GameEnvBackground from '/assets/js/GameEnginev1/essentials/GameEnvBackground.js';
# import Player from '/assets/js/GameEnginev1/essentials/Player.js';
# import Npc from '/assets/js/GameEnginev1/essentials/Npc.js';
#
# class QuestMakefile {
#   constructor(gameEnv) {
#     const path = gameEnv.path;
#     const width = gameEnv.innerWidth;
#     const height = gameEnv.innerHeight;
#
#     const bgData = {
#       name: 'quest2_bg',
#       src: path + '/images/gamify-tools/water.jpg',
#       pixels: { height: 720, width: 1280 }
#     };
#
#     const playerData = {
#       id: 'DevHero',
#       src: path + '/images/gamify-tools/chillguy.png',
#       SCALE_FACTOR: 5,
#       STEP_FACTOR: 1000,
#       ANIMATION_RATE: 50,
#       INIT_POSITION: { x: 50, y: height / 2 },
#       pixels: { height: 512, width: 384 },
#       orientation: { rows: 4, columns: 3 },
#       down: { row: 0, start: 0, columns: 3 },
#       downRight: { row: 1, start: 0, columns: 3, rotate: Math.PI / 16 },
#       downLeft: { row: 2, start: 0, columns: 3, rotate: -Math.PI / 16 },
#       right: { row: 1, start: 0, columns: 3 },
#       left: { row: 2, start: 0, columns: 3 },
#       up: { row: 3, start: 0, columns: 3 },
#       upRight: { row: 1, start: 0, columns: 3, rotate: -Math.PI / 16 },
#       upLeft: { row: 2, start: 0, columns: 3, rotate: Math.PI / 16 },
#       hitbox: { widthPercentage: 0.45, heightPercentage: 0.2 },
#       keypress: { up: 87, left: 65, down: 83, right: 68 }
#     };
#
#     // NPC: the Makefile itself
#     const makefileNpc = {
#       id: 'makefile_npc',
#       src: path + '/images/gamify-tools/robot.png',
#       SCALE_FACTOR: 5,
#       ANIMATION_RATE: 100,
#       INIT_POSITION: { x: width * 0.35, y: height / 2 },
#       pixels: { height: 256, width: 256 },
#       orientation: { rows: 1, columns: 1 },
#       down: { row: 0, start: 0, columns: 1 },
#       hitbox: { widthPercentage: 0.5, heightPercentage: 0.5 },
#       dialogues: [
#         'I am the Makefile! I automate your build process.',
#         'Define targets like `build`, `clean`, and `test`.',
#         'Run `make` in your terminal to execute the default target.',
#         'Objective complete: Makefile mastered! +80 pts'
#       ]
#     };
#
#     // NPC: the build target
#     const buildTargetNpc = {
#       id: 'build_target_npc',
#       src: path + '/images/gamify-tools/robot.png',
#       SCALE_FACTOR: 5,
#       ANIMATION_RATE: 100,
#       INIT_POSITION: { x: width * 0.65, y: height / 2 },
#       pixels: { height: 256, width: 256 },
#       orientation: { rows: 1, columns: 1 },
#       down: { row: 0, start: 0, columns: 1 },
#       hitbox: { widthPercentage: 0.5, heightPercentage: 0.5 },
#       dialogues: [
#         'I am the `build` target! I compile your source code.',
#         'build:\n\t@gcc -o app src/main.c',
#         'Use .PHONY to mark targets that are not file names.',
#         'Objective complete: build target unlocked! +80 pts'
#       ]
#     };
#
#     this.classes = [
#       { class: GameEnvBackground, data: bgData },
#       { class: Player, data: playerData },
#       { class: Npc, data: makefileNpc },
#       { class: Npc, data: buildTargetNpc },
#     ];
#   }
# }
#
# export const gameLevelClasses = [QuestMakefile];
# export { GameControl };

# %% [markdown]
# ## Quest 3: Merge Conflict
#
# > Two branches collide! Navigate the conflict zone, find the conflicting files, and resolve them to proceed.

# %%
# %%js
#
# // GAME_RUNNER: Quest 3 - Merge Conflict. Two branches collided! Find the conflict markers and resolve them. Use WASD to move.
#
# import GameControl from '/assets/js/GameEnginev1/essentials/GameControl.js';
# import GameEnvBackground from '/assets/js/GameEnginev1/essentials/GameEnvBackground.js';
# import Player from '/assets/js/GameEnginev1/essentials/Player.js';
# import Npc from '/assets/js/GameEnginev1/essentials/Npc.js';
#
# class QuestMergeConflict {
#   constructor(gameEnv) {
#     const path = gameEnv.path;
#     const width = gameEnv.innerWidth;
#     const height = gameEnv.innerHeight;
#
#     const bgData = {
#       name: 'quest3_bg',
#       src: path + '/images/gamify-tools/clouds.jpg',
#       pixels: { height: 720, width: 1280 }
#     };
#
#     const playerData = {
#       id: 'DevHero',
#       src: path + '/images/gamify-tools/chillguy.png',
#       SCALE_FACTOR: 5,
#       STEP_FACTOR: 1000,
#       ANIMATION_RATE: 50,
#       INIT_POSITION: { x: 50, y: height / 2 },
#       pixels: { height: 512, width: 384 },
#       orientation: { rows: 4, columns: 3 },
#       down: { row: 0, start: 0, columns: 3 },
#       downRight: { row: 1, start: 0, columns: 3, rotate: Math.PI / 16 },
#       downLeft: { row: 2, start: 0, columns: 3, rotate: -Math.PI / 16 },
#       right: { row: 1, start: 0, columns: 3 },
#       left: { row: 2, start: 0, columns: 3 },
#       up: { row: 3, start: 0, columns: 3 },
#       upRight: { row: 1, start: 0, columns: 3, rotate: -Math.PI / 16 },
#       upLeft: { row: 2, start: 0, columns: 3, rotate: Math.PI / 16 },
#       hitbox: { widthPercentage: 0.45, heightPercentage: 0.2 },
#       keypress: { up: 87, left: 65, down: 83, right: 68 }
#     };
#
#     // NPC: HEAD branch
#     const headBranchNpc = {
#       id: 'head_branch',
#       src: path + '/images/gamify-tools/robot.png',
#       SCALE_FACTOR: 5,
#       ANIMATION_RATE: 100,
#       INIT_POSITION: { x: width * 0.3, y: height / 2 },
#       pixels: { height: 256, width: 256 },
#       orientation: { rows: 1, columns: 1 },
#       down: { row: 0, start: 0, columns: 1 },
#       hitbox: { widthPercentage: 0.5, heightPercentage: 0.5 },
#       dialogues: [
#         'I am <<<<<<< HEAD — your current branch version.',
#         'Everything between me and ======= is YOUR code.',
#         'Decide: keep me, keep the other, or merge both.',
#         'Then delete ALL the conflict markers.'
#       ]
#     };
#
#     // NPC: incoming branch
#     const incomingBranchNpc = {
#       id: 'incoming_branch',
#       src: path + '/images/gamify-tools/robot.png',
#       SCALE_FACTOR: 5,
#       ANIMATION_RATE: 100,
#       INIT_POSITION: { x: width * 0.6, y: height / 2 },
#       pixels: { height: 256, width: 256 },
#       orientation: { rows: 1, columns: 1 },
#       down: { row: 0, start: 0, columns: 1 },
#       hitbox: { widthPercentage: 0.5, heightPercentage: 0.5 },
#       dialogues: [
#         'I am >>>>>>> feature-branch — the incoming change.',
#         'Everything between ======= and me is the OTHER branch.',
#         'After resolving: git add <file> && git commit.',
#         'Objective complete: Conflict resolved! +100 pts'
#       ]
#     };
#
#     this.classes = [
#       { class: GameEnvBackground, data: bgData },
#       { class: Player, data: playerData },
#       { class: Npc, data: headBranchNpc },
#       { class: Npc, data: incomingBranchNpc },
#     ];
#   }
# }
#
# export const gameLevelClasses = [QuestMergeConflict];
# export { GameControl };

# %% [markdown]
# ## Quest 4: Debug Protocol
#
# > A bug has been spotted in the codebase. Track it down by reading error messages, adding print statements, and fixing the root cause.

# %%
# %%js
#
# // GAME_RUNNER: Quest 4 - Debug Protocol. A bug is hiding in the code! Find and talk to the Error NPC, trace the stack, and squash the bug. Use WASD to move.
#
# import GameControl from '/assets/js/GameEnginev1/essentials/GameControl.js';
# import GameEnvBackground from '/assets/js/GameEnginev1/essentials/GameEnvBackground.js';
# import Player from '/assets/js/GameEnginev1/essentials/Player.js';
# import Npc from '/assets/js/GameEnginev1/essentials/Npc.js';
#
# class QuestDebug {
#   constructor(gameEnv) {
#     const path = gameEnv.path;
#     const width = gameEnv.innerWidth;
#     const height = gameEnv.innerHeight;
#
#     const bgData = {
#       name: 'quest4_bg',
#       src: path + '/images/gamify-tools/water.jpg',
#       pixels: { height: 720, width: 1280 }
#     };
#
#     const playerData = {
#       id: 'DevHero',
#       src: path + '/images/gamify-tools/chillguy.png',
#       SCALE_FACTOR: 5,
#       STEP_FACTOR: 1000,
#       ANIMATION_RATE: 50,
#       INIT_POSITION: { x: 50, y: height / 2 },
#       pixels: { height: 512, width: 384 },
#       orientation: { rows: 4, columns: 3 },
#       down: { row: 0, start: 0, columns: 3 },
#       downRight: { row: 1, start: 0, columns: 3, rotate: Math.PI / 16 },
#       downLeft: { row: 2, start: 0, columns: 3, rotate: -Math.PI / 16 },
#       right: { row: 1, start: 0, columns: 3 },
#       left: { row: 2, start: 0, columns: 3 },
#       up: { row: 3, start: 0, columns: 3 },
#       upRight: { row: 1, start: 0, columns: 3, rotate: -Math.PI / 16 },
#       upLeft: { row: 2, start: 0, columns: 3, rotate: Math.PI / 16 },
#       hitbox: { widthPercentage: 0.45, heightPercentage: 0.2 },
#       keypress: { up: 87, left: 65, down: 83, right: 68 }
#     };
#
#     // NPC: the error message
#     const errorNpc = {
#       id: 'error_npc',
#       src: path + '/images/gamify-tools/robot.png',
#       SCALE_FACTOR: 5,
#       ANIMATION_RATE: 100,
#       INIT_POSITION: { x: width * 0.3, y: height / 2 },
#       pixels: { height: 256, width: 256 },
#       orientation: { rows: 1, columns: 1 },
#       down: { row: 0, start: 0, columns: 1 },
#       hitbox: { widthPercentage: 0.5, heightPercentage: 0.5 },
#       dialogues: [
#         'TypeError: Cannot read properties of undefined',
#         '    at computeTotal (app.js:42)',
#         '    at main (app.js:78)',
#         'Start at the BOTTOM of the stack trace and work up.'
#       ]
#     };
#
#     // NPC: the fix
#     const fixNpc = {
#       id: 'fix_npc',
#       src: path + '/images/gamify-tools/robot.png',
#       SCALE_FACTOR: 5,
#       ANIMATION_RATE: 100,
#       INIT_POSITION: { x: width * 0.65, y: height / 2 },
#       pixels: { height: 256, width: 256 },
#       orientation: { rows: 1, columns: 1 },
#       down: { row: 0, start: 0, columns: 1 },
#       hitbox: { widthPercentage: 0.5, heightPercentage: 0.5 },
#       dialogues: [
#         'The fix: add a guard clause before accessing properties.',
#         'const items = data.items || [];',
#         'Always validate inputs before using them!',
#         'Objective complete: Bug squashed! +120 pts'
#       ]
#     };
#
#     this.classes = [
#       { class: GameEnvBackground, data: bgData },
#       { class: Player, data: playerData },
#       { class: Npc, data: errorNpc },
#       { class: Npc, data: fixNpc },
#     ];
#   }
# }
#
# export const gameLevelClasses = [QuestDebug];
# export { GameControl };

# %% [markdown]
# ## All Quests Combined
#
# > Play through all four quests in sequence using the level selector. Complete them in order to unlock the full Dev Quest experience.

# %%
# %%js
#
# // GAME_RUNNER: Dev Quest - Full Campaign. Use the level selector to navigate all four quests. Complete them in order!
#
# import GameControl from '/assets/js/GameEnginev1/essentials/GameControl.js';
# import GameEnvBackground from '/assets/js/GameEnginev1/essentials/GameEnvBackground.js';
# import Player from '/assets/js/GameEnginev1/essentials/Player.js';
# import Npc from '/assets/js/GameEnginev1/essentials/Npc.js';
#
# class QuestFileStructure {
#   constructor(gameEnv) {
#     const path = gameEnv.path;
#     const width = gameEnv.innerWidth;
#     const height = gameEnv.innerHeight;
#     this.classes = [
#       { class: GameEnvBackground, data: { name: 'q1_bg', src: path + '/images/gamify-tools/clouds.jpg', pixels: { height: 720, width: 1280 } } },
#       { class: Player, data: {
#           id: 'DevHero', src: path + '/images/gamify-tools/chillguy.png',
#           SCALE_FACTOR: 5, STEP_FACTOR: 1000, ANIMATION_RATE: 50,
#           INIT_POSITION: { x: 50, y: height / 2 },
#           pixels: { height: 512, width: 384 }, orientation: { rows: 4, columns: 3 },
#           down: { row: 0, start: 0, columns: 3 }, right: { row: 1, start: 0, columns: 3 },
#           left: { row: 2, start: 0, columns: 3 }, up: { row: 3, start: 0, columns: 3 },
#           downRight: { row: 1, start: 0, columns: 3, rotate: Math.PI/16 },
#           downLeft: { row: 2, start: 0, columns: 3, rotate: -Math.PI/16 },
#           upRight: { row: 1, start: 0, columns: 3, rotate: -Math.PI/16 },
#           upLeft: { row: 2, start: 0, columns: 3, rotate: Math.PI/16 },
#           hitbox: { widthPercentage: 0.45, heightPercentage: 0.2 },
#           keypress: { up: 87, left: 65, down: 83, right: 68 }
#       }},
#       { class: Npc, data: { id: 'src_folder', src: path + '/images/gamify/robot.png', SCALE_FACTOR: 5, ANIMATION_RATE: 100, INIT_POSITION: { x: width * 0.3, y: height / 2 }, pixels: { height: 256, width: 256 }, orientation: { rows: 1, columns: 1 }, down: { row: 0, start: 0, columns: 1 }, hitbox: { widthPercentage: 0.5, heightPercentage: 0.5 }, dialogues: ['I am src/ — put your source code here!', 'Objective 1 complete: +50 pts'] } },
#       { class: Npc, data: { id: 'readme', src: path + '/images/gamify/robot.png', SCALE_FACTOR: 5, ANIMATION_RATE: 100, INIT_POSITION: { x: width * 0.6, y: height / 2 }, pixels: { height: 256, width: 256 }, orientation: { rows: 1, columns: 1 }, down: { row: 0, start: 0, columns: 1 }, hitbox: { widthPercentage: 0.5, heightPercentage: 0.5 }, dialogues: ['I am README.md — describe your project here!', 'Quest 1 complete! +50 pts'] } },
#     ];
#   }
# }
#
# class QuestMakefile {
#   constructor(gameEnv) {
#     const path = gameEnv.path;
#     const width = gameEnv.innerWidth;
#     const height = gameEnv.innerHeight;
#     this.classes = [
#       { class: GameEnvBackground, data: { name: 'q2_bg', src: path + '/images/gamify-tools/water.jpg', pixels: { height: 720, width: 1280 } } },
#       { class: Player, data: {
#           id: 'DevHero', src: path + '/images/gamify-tools/chillguy.png',
#           SCALE_FACTOR: 5, STEP_FACTOR: 1000, ANIMATION_RATE: 50,
#           INIT_POSITION: { x: 50, y: height / 2 },
#           pixels: { height: 512, width: 384 }, orientation: { rows: 4, columns: 3 },
#           down: { row: 0, start: 0, columns: 3 }, right: { row: 1, start: 0, columns: 3 },
#           left: { row: 2, start: 0, columns: 3 }, up: { row: 3, start: 0, columns: 3 },
#           downRight: { row: 1, start: 0, columns: 3, rotate: Math.PI/16 },
#           downLeft: { row: 2, start: 0, columns: 3, rotate: -Math.PI/16 },
#           upRight: { row: 1, start: 0, columns: 3, rotate: -Math.PI/16 },
#           upLeft: { row: 2, start: 0, columns: 3, rotate: Math.PI/16 },
#           hitbox: { widthPercentage: 0.45, heightPercentage: 0.2 },
#           keypress: { up: 87, left: 65, down: 83, right: 68 }
#       }},
#       { class: Npc, data: { id: 'makefile_npc', src: path + '/images/gamify-tools/robot.png', SCALE_FACTOR: 5, ANIMATION_RATE: 100, INIT_POSITION: { x: width * 0.35, y: height / 2 }, pixels: { height: 256, width: 256 }, orientation: { rows: 1, columns: 1 }, down: { row: 0, start: 0, columns: 1 }, hitbox: { widthPercentage: 0.5, heightPercentage: 0.5 }, dialogues: ['I am the Makefile!', 'Define targets: build, clean, test.', 'Run `make` to execute. +80 pts'] } },
#       { class: Npc, data: { id: 'build_target', src: path + '/images/gamify-tools/robot.png', SCALE_FACTOR: 5, ANIMATION_RATE: 100, INIT_POSITION: { x: width * 0.65, y: height / 2 }, pixels: { height: 256, width: 256 }, orientation: { rows: 1, columns: 1 }, down: { row: 0, start: 0, columns: 1 }, hitbox: { widthPercentage: 0.5, heightPercentage: 0.5 }, dialogues: ['I am the `build` target!', 'build:\n\t@gcc -o app src/main.c', 'Quest 2 complete! +80 pts'] } },
#     ];
#   }
# }
#
# class QuestMergeConflict {
#   constructor(gameEnv) {
#     const path = gameEnv.path;
#     const width = gameEnv.innerWidth;
#     const height = gameEnv.innerHeight;
#     this.classes = [
#       { class: GameEnvBackground, data: { name: 'q3_bg', src: path + '/images/gamify-tools/clouds.jpg', pixels: { height: 720, width: 1280 } } },
#       { class: Player, data: {
#           id: 'DevHero', src: path + '/images/gamify-tools/chillguy.png',
#           SCALE_FACTOR: 5, STEP_FACTOR: 1000, ANIMATION_RATE: 50,
#           INIT_POSITION: { x: 50, y: height / 2 },
#           pixels: { height: 512, width: 384 }, orientation: { rows: 4, columns: 3 },
#           down: { row: 0, start: 0, columns: 3 }, right: { row: 1, start: 0, columns: 3 },
#           left: { row: 2, start: 0, columns: 3 }, up: { row: 3, start: 0, columns: 3 },
#           downRight: { row: 1, start: 0, columns: 3, rotate: Math.PI/16 },
#           downLeft: { row: 2, start: 0, columns: 3, rotate: -Math.PI/16 },
#           upRight: { row: 1, start: 0, columns: 3, rotate: -Math.PI/16 },
#           upLeft: { row: 2, start: 0, columns: 3, rotate: Math.PI/16 },
#           hitbox: { widthPercentage: 0.45, heightPercentage: 0.2 },
#           keypress: { up: 87, left: 65, down: 83, right: 68 }
#       }},
#       { class: Npc, data: { id: 'head_branch', src: path + '/images/gamify-tools/robot.png', SCALE_FACTOR: 5, ANIMATION_RATE: 100, INIT_POSITION: { x: width * 0.3, y: height / 2 }, pixels: { height: 256, width: 256 }, orientation: { rows: 1, columns: 1 }, down: { row: 0, start: 0, columns: 1 }, hitbox: { widthPercentage: 0.5, heightPercentage: 0.5 }, dialogues: ['I am <<<<<<< HEAD — your current branch.', 'Keep me, keep them, or merge both.', 'Then delete ALL conflict markers. +100 pts'] } },
#       { class: Npc, data: { id: 'incoming_branch', src: path + '/images/gamify-tools/robot.png', SCALE_FACTOR: 5, ANIMATION_RATE: 100, INIT_POSITION: { x: width * 0.6, y: height / 2 }, pixels: { height: 256, width: 256 }, orientation: { rows: 1, columns: 1 }, down: { row: 0, start: 0, columns: 1 }, hitbox: { widthPercentage: 0.5, heightPercentage: 0.5 }, dialogues: ['I am >>>>>>> feature-branch — the incoming change.', 'After resolving: git add && git commit.', 'Quest 3 complete! +100 pts'] } },
#     ];
#   }
# }
#
# class QuestDebug {
#   constructor(gameEnv) {
#     const path = gameEnv.path;
#     const width = gameEnv.innerWidth;
#     const height = gameEnv.innerHeight;
#     this.classes = [
#       { class: GameEnvBackground, data: { name: 'q4_bg', src: path + '/images/gamify-tools/water.jpg', pixels: { height: 720, width: 1280 } } },
#       { class: Player, data: {
#           id: 'DevHero', src: path + '/images/gamify-tools/chillguy.png',
#           SCALE_FACTOR: 5, STEP_FACTOR: 1000, ANIMATION_RATE: 50,
#           INIT_POSITION: { x: 50, y: height / 2 },
#           pixels: { height: 512, width: 384 }, orientation: { rows: 4, columns: 3 },
#           down: { row: 0, start: 0, columns: 3 }, right: { row: 1, start: 0, columns: 3 },
#           left: { row: 2, start: 0, columns: 3 }, up: { row: 3, start: 0, columns: 3 },
#           downRight: { row: 1, start: 0, columns: 3, rotate: Math.PI/16 },
#           downLeft: { row: 2, start: 0, columns: 3, rotate: -Math.PI/16 },
#           upRight: { row: 1, start: 0, columns: 3, rotate: -Math.PI/16 },
#           upLeft: { row: 2, start: 0, columns: 3, rotate: Math.PI/16 },
#           hitbox: { widthPercentage: 0.45, heightPercentage: 0.2 },
#           keypress: { up: 87, left: 65, down: 83, right: 68 }
#       }},
#       { class: Npc, data: { id: 'error_npc', src: path + '/images/gamify-tools/robot.png', SCALE_FACTOR: 5, ANIMATION_RATE: 100, INIT_POSITION: { x: width * 0.3, y: height / 2 }, pixels: { height: 256, width: 256 }, orientation: { rows: 1, columns: 1 }, down: { row: 0, start: 0, columns: 1 }, hitbox: { widthPercentage: 0.5, heightPercentage: 0.5 }, dialogues: ['TypeError: Cannot read properties of undefined', 'at computeTotal (app.js:42)', 'Start at the bottom of the stack trace!'] } },
#       { class: Npc, data: { id: 'fix_npc', src: path + '/images/gamify-tools/robot.png', SCALE_FACTOR: 5, ANIMATION_RATE: 100, INIT_POSITION: { x: width * 0.65, y: height / 2 }, pixels: { height: 256, width: 256 }, orientation: { rows: 1, columns: 1 }, down: { row: 0, start: 0, columns: 1 }, hitbox: { widthPercentage: 0.5, heightPercentage: 0.5 }, dialogues: ['Fix: const items = data.items || [];', 'Always guard against undefined!', 'Quest 4 complete! Campaign finished! +120 pts'] } },
#     ];
#   }
# }
#
# export const gameLevelClasses = [QuestFileStructure, QuestMakefile, QuestMergeConflict, QuestDebug];
# export { GameControl };

# %% [markdown]
# ## Quest Design Guide
#
# Each quest follows the same pattern:
#
# - **Background**: Sets the visual scene for the quest
# - **Player**: The Dev Hero the student controls with WASD
# - **NPCs**: Characters that represent concepts (files, errors, targets) and deliver dialogue when approached
# - **Dialogues**: Step through lesson content by walking up to NPCs and pressing the interact key
#
# ### Adding a New Quest
#
# 1. Create a new `%%js` code cell
# 2. Add `// GAME_RUNNER: <your challenge description>`
# 3. Define a new level class with the concept NPCs
# 4. Export `gameLevelClasses` and `GameControl`
# 5. Run `make` to convert and test on the web
#
# ### Scoring Ideas
#
# Embed point values in NPC dialogue lines so students know what each interaction is worth:
#
# ```javascript
# dialogues: [
#   'I am the Makefile!',
#   'Objective complete: +80 pts'
# ]
# ```
