# %% [raw]
# ---
# layout: post
# title: Open Coding Society Home - Gamified Pilot
# description: MVP-A pilot for zone-based on-demand game panels.
# permalink: /home-gamified-mvp
# hide: true
# toc: false
# ---

# %% [markdown]
# ## Gamified Home Pilot (MVP-A)
#
# Phase 1 scaffold is active. Next step is moving zone UI and game panel logic from index into UI_RUNNER and GAME_RUNNER cells.
