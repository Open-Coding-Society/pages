# %%
---
layout: post
tailwind: true
title: Sprint 4 - CSSE Objectives 
description: Exploring the Game Engine 
courses: { csse: {week: 13} }
permalink: /csse/sprint4/objectives

Games:
  - title: "GameEngine V1 Collection"
    image: "gamify/lessons/adventure.png"
    alt: "GameEngine V1 Collection"
    link: "/gamify/adventureGame"
    lessonLink: "/gamify/topics"
    category: "Adventure"
    difficulty: "Beginner"
    description: "This page contains example games and levels."
    author: "Student Community"
    keyPoints:
      - "Background, Players, and NPCs"
      - "Interact function"
      - "Reaction function"
      - "Game-in-Game"

  - title: "Fortune Finders"
    image: "gamify/lessons/fortune.png"
    alt: "Fortune Finders"
    link: "/gamify/fortuneFinders"
    lessonLink: "/gamify/topics"
    category: "Finance"
    difficulty: "Intermediate"
    description: "This page contains games developed for finance simulations."
    author: "Student Community"
    keyPoints:
      - "Interactive NPC conversations"
      - "CS knowledge questions"
      - "Virtual currency system"
      - "Multiple game modes"
      - "Crypto trading simulation"

  - title: "Platformer Game Engine"
    image: "gamify/lessons/platformer.png"
    alt: "Mario-style Platformer"
    link: "/navigation/game"
    lessonLink: "/gamify/topics/"
    category: "Action"
    difficulty: "Advanced"
    description: "Using an GameEngine V1 predecessor, students will learn game development concepts through a classic Mario-style platformer game."
    author: "Student Community"
    keyPoints:
      - "Game physics simulation"
      - "Collision detection algorithms"
      - "Sprite animation techniques"
      - "Level design principles"
      - "Team collaboration tools"

  - title: "Mansion Game"
    image: "gamify/lessons/mansionGame.png"
    alt: "Mansion Game"
    link: "/gamify/mansionGame"
    lessonLink: "/gamify/topics/"
    category: "Adventure"
    difficulty: "Beginner"
    description: "A text-based adventure game set in a mysterious mansion, where players solve puzzles and uncover secrets."
    author: "Student Community"
    keyPoints:
      - "Text-based adventure mechanics"
      - "Puzzle design"
      - "Storytelling and narrative"
      - "Player decision-making"

  - title: "Murder Mystery Game"
    image: "gamify/lessons/murderMystery.png"
    alt: "Murder Mystery Game"
    link: "/gamify/murderMystery"
    lessonLink: "/gamify/topics/"
    category: "Adventure"
    difficulty: "Intermediate"
    description: "A murder mystery game where players gather clues, interrogate suspects, and solve the crime."
    author: "Student Community"
    keyPoints:
      - "Investigation mechanics"
      - "Clue collection"
      - "Interrogation techniques"
      - "Deduction and reasoning"

---

# %% [markdown]
#   <!-- Call to Action Section -->
#   <div class="rounded-xl p-8 border mb-12 transition-all duration-300 hover:scale-105 bg-gray-700 transition-all duration-300 transform hover:scale-105">
#     <div class="flex items-center justify-center">
#         <h2 class="text-3xl font-bold text-white mb-4">Ready to Level Up Your Coding Skills?</h2>
#     </div>
#     <p class="mb-6 text-base text-primary-content">
#         The games below combine fun and learning to make computer science concepts accessible and engaging. Review the required tools and background, select a game that interests you, and begin your coding adventure!
#     </p>
#     <div class="flex flex-wrap justify-center gap-4">
#       <a href="{{ site.baseurl }}/tools/" class="bg-accent text-accent-content px-6 py-3 rounded-lg font-semibold hover:opacity-90 transition-all duration-300 transform hover:scale-105">
#         🛠️ Required Development Tools
#       </a>
#       <a href="{{ site.baseurl }}/javascript/variables/dom/csse/" class="bg-secondary text-secondary-content px-6 py-3 rounded-lg font-semibold hover:opacity-90 transition-all duration-300 transform hover:scale-105">
#         📚 Required JavaScript Background
#       </a>
#     </div>
#   </div>

# %% [markdown]
# <div class="container mx-auto px-4 py-8">
#
#   <!-- Team and Objectives Grid -->
#   <div class="grid grid-cols-1 md:grid-cols-2 gap-6 mb-8">
#     <!-- Team Setup Card -->
#     <div class="bg-gray-800 rounded-xl p-6 border border-blue-600 hover:border-blue-400 transition-all duration-300">
#       <div class="flex items-center mb-4">
#         <h3 class="text-xl font-bold text-white">Team Repository</h3>
#       </div>
#       <p class="mb-3">
#         Each team will create a repository using the OCS pages template.
#       </p>
#       <div class="bg-blue-900 bg-opacity-30 rounded-lg p-3 text-sm text-blue-200">
#         <strong>Team Size:</strong> 5-6 members
#       </div>
#     </div>
#     <!-- Game Levels Card -->
#     <div class="bg-gray-800 rounded-xl p-6 border border-green-600 hover:border-green-400 transition-all duration-300">
#       <div class="flex items-center mb-4">
#         <h3 class="text-xl font-bold text-white">Customize Game Levels</h3>
#       </div>
#       <p class="mb-3">
#         Your team will manage, update, and customize multiple game levels.
#       </p>
#       <div class="bg-green-900 bg-opacity-30 rounded-lg p-3 text-sm text-green-200">
#         <strong>Focus:</strong> Design engaging levels with unique challenges
#       </div>
#     </div>
#     <!-- Story Development Card -->
#     <div class="bg-gray-800 rounded-xl p-6 border border-purple-600 hover:border-purple-400 transition-all duration-300">
#       <div class="flex items-center mb-4">
#         <h3 class="text-xl font-bold text-white">Establish Your Story</h3>
#       </div>
#       <p class="mb-3">
#         Each team will develop a compelling story and decide how the game ends.
#       </p>
#       <div class="bg-purple-900 bg-opacity-30 rounded-lg p-3 text-sm text-purple-200">
#         <strong>Creative Goal:</strong> Build the narrative and game conclusion
#       </div>
#     </div>
#     <!-- Pair Programming Card -->
#     <div class="bg-gray-800 rounded-xl p-6 border border-orange-600 hover:border-orange-400 transition-all duration-300">
#       <div class="flex items-center mb-4">
#         <h3 class="text-xl font-bold text-white">Pair Work & Review</h3>
#       </div>
#       <p class="mb-3">
#         Work in 2s (or 3s if needed) to prepare your final review, covering planning, coding, and contributions.
#       </p>
#       <div class="bg-orange-900 bg-opacity-30 rounded-lg p-3 text-sm text-orange-200">
#         <strong>Deliverable:</strong> Live reviews, weekly formative checkpoints and summative sprint retrospective
#       </div>
#     </div>
#
#   </div>
#
# </div>

# %% [markdown]
# <div class="bg-gray-800 rounded-xl p-8 text-center border mb-12">
# <!-- Objectives Header -->
# <div class="rounded-xl p-6 text-center border">
# <div class="flex items-center justify-center mb-3">
#     <h3 class="text-3xl font-bold">Game Coding Challenge</h3>
# </div>
# <p class="text-lg">
#     In teams of 5–6, you’ll work on a collaborative game project. Change, add, or extend levels in the game (ie mansion or mystery game) to create an unforgettable experience!
# </p>
# </div>
# </div>

# %% [markdown]
# <div class="container mx-auto px-4 py-8">
#
#   <!-- Game Cards Grid - Responsive: 1 on mobile, 2 on tablet, 3-4 on desktop -->
#   <div class="grid grid-cols-1 md:grid-cols-2 lg:grid-cols-2 xl:grid-cols-3 gap-6 mb-12">
#     {% for game in page.Games %}
#       <div class="bg-gray-800 rounded-xl shadow-lg hover:shadow-2xl transition-all duration-300 overflow-hidden group transform hover:-translate-y-2">
#         <!-- Game Image Container -->
#         <div class="relative h-48 overflow-hidden bg-gradient-to-br from-gray-700 to-gray-900">
#           <!-- Make the entire image area clickable -->
#           <a href="{{ site.baseurl }}{{ game.link }}" class="block w-full h-full">
#             <img src="{{ site.baseurl }}/images/{{ game.image }}"
#                  alt="{{ game.alt }}"
#                  class="w-full h-full object-cover transition-all duration-300 group-hover:scale-110">
#           </a>
#           <!-- Category Badge -->
#           {% if game.category %}
#           <div class="absolute top-3 left-3 bg-black bg-opacity-80 text-white px-2 py-1 rounded-full text-xs font-semibold pointer-events-none">
#             {{ game.category }}
#           </div>
#           {% endif %}
#           <!-- Difficulty Badge -->
#           {% if game.difficulty %}
#           <div class="absolute top-3 right-3 bg-blue-600 bg-opacity-90 text-white px-2 py-1 rounded-full text-xs font-semibold pointer-events-none">
#             {{ game.difficulty }}
#           </div>
#           {% endif %}
#           <!-- Play Overlay - Now clickable -->
#           <div class="absolute inset-0 bg-opacity-50 opacity-0 group-hover:opacity-100 transition-opacity duration-300 flex items-center justify-center pointer-events-none">
#             <div class="bg-opacity-90 bg-black rounded-full p-4 flex items-center justify-center">
#               <span class="text-4xl leading-none">▶</span>
#             </div>
#           </div>
#         </div>
#         <!-- Game Info -->
#         <div class="p-6">
#           <!-- Title and Author -->
#           <div class="mb-3">
#             <h3 class="text-xl font-bold mb-1">{{ game.title }}</h3>
#             {% if game.author %}
#             <p class="text-sm">{{ game.author }}</p>
#             {% endif %}
#           </div>
#           <!-- Description -->
#           {% if game.description %}
#           <p class="text-sm mb-4 line-clamp-3">{{ game.description }}</p>
#           {% endif %}
#           <!-- Key Learning Points -->
#           {% if game.keyPoints %}
#           <div class="mb-4">
#             <h4 class="text-sm font-semibold text-gray-200 mb-2">What You'll Learn:</h4>
#             <div class="flex flex-wrap gap-1">
#               {% for point in game.keyPoints limit:3 %}
#                 <span class="bg-gradient-to-r from-green-400 to-green-300 text-white text-xs px-2 py-1 rounded-full">{{ point }}</span>
#               {% endfor %}
#             </div>
#           </div>
#           {% endif %}
#           <!-- Dual Action Buttons -->
#           <div class="flex gap-2">
#             <!-- Play Game Button (uses link) -->
#             <a href="{{ site.baseurl }}{{ game.link }}"
#                class="flex-1 bg-gradient-to-r from-green-600 to-green-500 text-white text-center py-3 rounded-lg font-semibold hover:from-green-500 hover:to-green-400 transition-all duration-300 transform hover:scale-105">
#               🎮 Play Game
#             </a>
#             <!-- Start Learning Button (uses lessonLink) -->
#             {% if game.lessonLink %}
#             <a href="{{ site.baseurl }}{{ game.lessonLink }}"
#                class="flex-1 bg-gradient-to-r from-blue-400 to-purple-400 text-white text-center py-3 rounded-lg font-semibold hover:from-blue-400 hover:to-purple-400 transition-all duration-300 transform hover:scale-105">
#               📚 Learn More
#             </a>
#             {% endif %}
#           </div>
#         </div>
#       </div>
#     {% endfor %}
#   </div>
#
# </div>
#
# <style>
#   .line-clamp-3 {
#     display: -webkit-box;
#     -webkit-line-clamp: 3;
#     -webkit-box-orient: vertical;
#     overflow: hidden;
#   }
# </style>

# %% [markdown]
#   <div class="bg-gray-800 rounded-xl p-8 text-center border mb-12">
#   <!-- Final Team Review Banner -->
#   <div class="rounded-xl p-6 text-center border">
#     <div class="flex items-center justify-center mb-3">
#       <h3 class="text-3xl font-bold">Final Team Review</h3>
#     </div>
#     <p class="text-lg">
#       Each team will prepare and present a comprehensive final review, showcasing your game, story, and technical achievements.
#     </p>
#   </div>
#   </div>
