# %% [markdown]
# ## Homework
#
# **Requirements:**
#
# - Include three strings
# - Find the length of each string and print them
# - Find the first and last character of each string and print them
# - Concatenate all three strings and print the result

# %%
# %%js
#
# // Your code here:
