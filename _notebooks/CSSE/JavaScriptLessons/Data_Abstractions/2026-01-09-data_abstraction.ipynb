# %% [raw]
# ---
# title: Data Abstraction
# comments: true
# codemirror: true
# microblog: true
# layout: post
# permalink: /js/dataabstraction
# description: How Data Abstraction is used in Programming
# author: Rashi, Rigved, and Jasan
# ---

# %% [markdown]
# # What is Data Abstraction??
# <font color="blue"> IMAGINE </font>
# Simply driving a steering wheel without understanding how the parts inside work. This is exactly what Data Abstraction is.
#
# Data Abstraction simplifies complex systems by showing only the <font color= "red"> essential </font> features and hiding complex details, so users can easily understand and interact with systems or apps!
#
# <font color="green"> It focuses on *what* something does rather than *how* it does it. </font>
#
# # Data Abstraction in Functions
# Firstly, it can be shown through functions
#
# One example of abstraction is <font color="red"> built-in functions </font> in JavaScript, because they allow you to use one simple, clear command to run a type of function, but you don't see <u> how </u>the function was coded.

# %%
# %%js
# // CODE_RUNNER: Round the 'messy' number
#
# // Abstraction in Action: Math.round()
#
# // The Complex Data (Input)
# const messyNumber = 7.84236;
#
#
# // We call the built-in function.
# // We don't care how it calculates the rounding
#
# // only that it does the rounding
# const roundedResult = Math.round(messyNumber);
#
# // The Result (Output)
# console.log(`The original messy number was: ${messyNumber}`);
# console.log(`The simplified, rounded result is: ${roundedResult}`);
# // Expected output: 8

# %% [markdown]
# ## What's hidden:
# The internal logic behind our JavaScript code looks at the decimal part (.84236), determines that it's greater than 0.5, and then increments the integer part (7 -> 8). All of this is hidden by <u> abstraction</u>.

# %%
# %%js
# // CODE_RUNNER: The code below is "broken". Complete the function so that it successfully returns the sum of the two inputs.
#
# // The user should be able to call addNumbers(a, b) and trust it works without needing to see the math inside.
# // hint: use the 'return' keyword inside the function
#
# // The Abstraction (The Function)
# function addNumbers(num1, num2) {
#     // Add code here
#
# }
#
# let a = 2
# let b = 3
#
# // Use the abstraction to get the result
# let result = addNumbers(a, b);
#
# console.log(result);

# %% [markdown]
# # Data Abstraction with Classes
# Secondly, Data Abstraction can be seen in Object Oriented Programming, specifically with <font color="red"> Classes and Objects </font>. Classes are essential tools for <font color="red"> simplifying how we handle data. </font>

# %%
# %%js
# // CODE_RUNNER: Use abstraction to deposite $200 into the account
# class BankAccount {
#     constructor() {
#         this.balance = 500;
#     }
#
#     deposit(amount) {
#         this.balance = this.balance + amount;
#         console.log("💰 Deposited: $" + amount);
#     }
# }
#
# const myAccount = new BankAccount();
#
# // Write code here
# // Hint: myAccount.______();
#
# // 3. Check the result
# console.log("Final Balance: $" + myAccount.balance);

# %% [markdown]
# ## Inheritance
# In computer science, inheritance is when a class (called a subclass or child class) <font color="red"> inherits </font> properties and methods from another class (called a superclass or parent class). The parent <b> abstracts </b> common features, while the child class <b> inherits </b> details and defines their own new methods <b> without needing to know the internal details </b>.

# %%
# %%js
# // CODE_RUNNER: Data Abstraction with Inheritance

# %% [markdown]
# ## Polymorphism
# Polymorphism with data abstraction means different child classes use the same parent method in their own way, while the code using them doesn’t need to know their specific type. The parant <b> abstracts <b> the methods that must exist, while the child classes each provide <b> their own logic </b> for each of those methods.

# %%
# %%js
# // CODE_RUNNER: Data Abstraction with Polymorphism

# %% [markdown]
# ## HOMEWORK

# %% [markdown]
# ### This is a code of a calculator. Please read through the code first to try and understand what it does. There are many unessacary lines within the code. Please identify the unessacary lines and delete them.
