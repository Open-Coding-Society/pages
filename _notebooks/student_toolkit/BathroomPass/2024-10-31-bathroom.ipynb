# %% [raw]
# ---
# title: Bathroom
# layout: aesthetihawk
# active_tab: Dashboard
# toc: false
# permalink: /bathroom
# ---

# %% [markdown]
# <div class="w-full">
#     <div class="space-y-4 sm:space-y-6">
#         <div class="text-sm font-medium text-center border-b text-neutral-400 border-neutral-700">
#             <ul class="flex flex-wrap -mb-px">
#                 <li class="me-2">
#                     <a href="#"
#                         class="inline-block p-4 border-b-2 rounded-t-lg active text-blue-500 border-blue-500"
#                         aria-current="page">Bathroom Pass</a>
#                 </li>
#                 <li class="me-2">
#                     <a href="#"
#                         class="inline-block p-4 border-b-2 border-transparent rounded-t-lg hover:border-neutral-300 hover:text-neutral-300">Bathroom
#                         Issues</a>
#                 </li>
#                 <li class="me-2">
#                     <a href="#"
#                         class="inline-block p-4 border-b-2 border-transparent rounded-t-lg hover:border-neutral-300 hover:text-neutral-300">Hall Pass</a>
#                 </li>
#             </ul>
#         </div>
#
#         <!-- Grid -->
#         <div class="flex flex-row gap-x-4 pt-2 sm:pt-0">
#             <div>
#                 <a class="py-3 px-4 inline-flex justify-center items-center gap-x-2 text-sm font-medium rounded-lg border border-transparent bg-blue-600 text-white hover:bg-blue-700 focus:outline-hidden focus:bg-blue-700 disabled:opacity-50 disabled:pointer-events-none"
#                     href="#">
#                     Add me to the queue.
#                 </a>
#             </div>
#
#             <div>
#                 <a class="py-3 px-4 inline-flex justify-center items-center gap-x-2 text-sm font-medium rounded-lg border border-transparent bg-blue-600 text-white hover:bg-blue-700 focus:outline-hidden focus:bg-blue-700 disabled:opacity-50 disabled:pointer-events-none"
#                     href="#">
#                     Remove me from the queue.
#                 </a>
#             </div>
#         </div>
#
#
#         <div class="grid sm:grid-cols-2 lg:grid-cols-3 gap-4 sm:gap-6">
#             <!-- Card -->
#             <div class="flex flex-col border shadow-2xs rounded-xl bg-neutral-800 border-neutral-700">
#                 <div class="p-4 md:p-5">
#                     <div class="flex items-center gap-x-2">
#                         <p class="text-xs uppercase text-neutral-500">
#                             Queue length
#                         </p>
#                         <div class="hs-tooltip">
#                             <div class="hs-tooltip-toggle">
#                                 <svg class="shrink-0 size-4 text-neutral-500" xmlns="http://www.w3.org/2000/svg"
#                                     width="24" height="24" viewBox="0 0 24 24" fill="none" stroke="currentColor"
#                                     stroke-width="2" stroke-linecap="round" stroke-linejoin="round">
#                                     <circle cx="12" cy="12" r="10" />
#                                     <path d="M9.09 9a3 3 0 0 1 5.83 1c0 2-3 3-3 3" />
#                                     <path d="M12 17h.01" />
#                                 </svg>
#                                 <span
#                                     class="hs-tooltip-content hs-tooltip-shown:opacity-100 hs-tooltip-shown:visible opacity-0 transition-opacity inline-block absolute invisible z-10 py-1 px-2 bg-neutral-900 text-xs font-medium text-white rounded-md shadow-2xs dark:bg-neutral-700 hidden"
#                                     role="tooltip">
#                                     The number of people in the queue right now.
#                                 </span>
#                             </div>
#                         </div>
#                     </div>
#
#                     <div class="mt-1 flex items-center gap-x-2">
#                         <h3 class="text-xl sm:text-2xl font-medium text-neutral-200">
#                             46
#                         </h3>
#                     </div>
#                 </div>
#             </div>
#             <!-- End Card -->
#
#             <!-- Card -->
#             <div class="flex flex-col border shadow-2xs rounded-xl bg-neutral-800 border-neutral-700">
#                 <div class="p-4 md:p-5">
#                     <div class="flex items-center gap-x-2">
#                         <p class="text-xs uppercase text-neutral-500">
#                             Your position in line
#                         </p>
#                     </div>
#
#                     <div class="mt-1 flex items-center gap-x-2">
#                         <h3 class="text-xl sm:text-2xl font-medium text-neutral-200">
#                             35
#                         </h3>
#                     </div>
#                 </div>
#             </div>
#             <!-- End Card -->
#
#             <!-- Card -->
#             <div class="flex flex-col border shadow-2xs rounded-xl bg-neutral-800 border-neutral-700">
#                 <div class="p-4 md:p-5">
#                     <div class="flex items-center gap-x-2">
#                         <p class="text-xs uppercase text-neutral-500">
#                             Estimated wait time
#                         </p>
#                     </div>
#
#                     <div class="mt-1 flex items-center gap-x-2">
#                         <h3 class="text-xl sm:text-2xl font-medium text-neutral-200">
#                             54 mins.
#                         </h3>
#                     </div>
#                 </div>
#             </div>
#             <!-- End Card -->
#         </div>
#         <!-- End Grid -->
#
#         <div class="grid lg:grid-cols-1 gap-4 sm:gap-6">
#             <!-- Card -->
#             <div
#                 class="p-4 md:p-5 min-h-102.5 flex flex-col border shadow-2xs rounded-xl bg-neutral-800 border-neutral-700">
#                 <!-- Header -->
#                 <div class="flex flex-wrap justify-between items-center gap-2">
#                     <div>
#                         <p class="text-xl sm:text-2xl font-medium text-neutral-200">
#                             Queue List
#                         </p>
#                     </div>
#                 </div>
#                 <!-- End Header -->
#
#                 <div id="hs-multiple-bar-charts"></div>
#             </div>
#             <!-- End Card -->
#         </div>
#     </div>
# </div>
