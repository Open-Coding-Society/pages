// %% [raw]
// ---
// layout: post
// courses: { csa: {week: 19} }
// toc: true
// codemirror: true
// title: 2014 FRQ Q2 - Writing a Class
// year: 2014
// frq_number: 1
// unit: [Big Idea Unit Here i.e. Unit 1]
// category: Class Design
// description: "AP CSA {{ page.year }} FRQ #{{ page.frq_no }} - {{ page.unit }} - {{ page.category }}"
// permalink: /csa/frqs/2014/1/q2
// author: Gamers - Avika
// ---

// %% [markdown]
// ## FRQ Question 2
//
//
// This question involves reasoning about the GridWorld case study. Reference materials are provided in the
// appendixes.
//
// <img src="{{site.baseurl}}/images/2014_FRQ_Q2.png">
//
// Write the complete <code>Director</code> class, including the zero-parameter constructor and any necessary instance
// variables and methods. Assume that the <code>Color</code> class has been imported.

// %%
// CODE_RUNNER: Director
import info.gridworld.actor.Actor;
import info.gridworld.actor.Rock;
import info.gridworld.grid.Grid;
import info.gridworld.grid.Location;
import java.awt.Color;
import java.util.ArrayList;

public class Director extends Rock {

    /** 
     * Constructs a Director with an initial color of Color.RED.
     */
    public Director() {
        // WRITE YOUR CODE HERE
    }

    /**
     * Alternates color between Color.RED and Color.GREEN each time it acts.
     * 
     * If the color is Color.GREEN when it BEGINS to act,
     * all neighboring Actors turn 90 degrees to the right.
     */
    public void act() {
        // WRITE YOUR CODE HERE
    }

    /**
     * Optional helper method to turn all neighboring
     * actors 90 degrees to the right.
     */
    private void turnNeighborsRight() {
        // WRITE YOUR CODE HERE (OPTIONAL)
    }

    /** Optional main method for testing */
    public static void main(String[] args) {
        // Example placeholder – students may modify.
        System.out.println("Director test stub — add GridWorld setup here.");
    }
}

// Run the main method
Director.main(null);

// %% [markdown]
// ## Scoring Guidelines
// <button onclick="document.getElementById('answerkey').style.display='block'">
//   Answer Key - Expected Code
// </button>
//
// <img id="answerkey" src="{{site.baseurl}}/images/2014_FRQ_Q2_Key.png" style="display:none;">
//
// ### Point Breakdown
//
// <button onclick="document.getElementById('points').style.display='block'">
//   Point Breakdown
// </button>
//
// <img id="points" src="{{site.baseurl}}/images/2014_FRQ_Q2_ptbrkdwn.png" style="display:none;">
