# %% [raw]
# ---
# title: Data Abstraction!
# comments: true
# codemirror: true
# layout: post
# permalink: /dataabstraction
# description: How Data Abstraction is used in Programming
# author: Rashi, Rigved, and Jasan
# ---

# %% [markdown]
# ## What are Data Abstractions?
# <font color="blue"> IMAGINE </font> Simply driving a steering wheel without understanding how the parts inside work.
#
# Data Abstraction simplifies complex systems by showing only the essential features and hiding complex details, so users can easily understand and interact with systems or apps!
#
# <font color="green"> It focuses on *what* something does rather than *how* it does it. </font>
#
# ## Examples
# In JavaScript, Data Abstraction is shown through various topics and is seamlessly implemented in many parts of our code.
#
# Firstly, it can be shown in built-in functions
#
# ## Example #1: Rounding numbers
# One example is <font color="red"> built-in functions </font> in JavaScript, because they allow you to use one simple, clear command to run a type of function, but don't show *how* the built-in function was coded.

# %%
# %%js
# // --- Abstraction in Action: Math.round() ---
#
# // 1. The Complex Data (Input)
# const messyNumber = 7.84236;
#
#
# // We call the built-in function. We don't care *how* it calculates the rounding,
# // only that it *does* the rounding.
# const roundedResult = Math.round(messyNumber);
#
# // 3. The Simple Result (Output)
# console.log(`The original messy number was: ${messyNumber}`);
# console.log(`The simplified, rounded result is: ${roundedResult}`);
# // Expected output: 8
#
# /*
# What's hidden (The Implementation):
# The specific machine code and internal logic the JavaScript engine uses
# to look at the decimal part (.84236), determine it's >= 0.5, and then
# increment the integer part (7 -> 8). All of that is abstracted away.
# */

# %% [markdown]
# ## Example #2: Adding two numbers
# Another great example of data abstraction for built-in functions would be a function that allows for the user to <font color="red"> easily </font> add two numbers

# %%
# %%js
# // CODE_RUNNER: Display two numbers, and add them!
# // 1. The Abstraction (The Function)
# // --- The Abstraction ---
# function addNumbers(num1, num2) {
#     return num1 + num2;
# }
#
# // --- The Data Abstraction and function Logic ---
# function handleAddition() {
#     // Get the values from the input boxes (Input Variables)
#     let a = 2
#     let b = 3
#
#     // Use the abstraction to get the result
#     // (We use Number() to make sure JS treats them as math, not text)
#     let result = addNumbers(a, b);
#
#     // Display the result (Output)
#     console.log(result);
# }

# %%
## Example #3: Classes
Secondly, Data Abstraction can be shown in Classes of object-oriented programming  
Classes are essential tools for <font color="red"> simplifying how we handle </font> data.

#1 Reusing Code and Inheritance: 

Once you create a class, you can use it over and over again to make new "objects" without having to type the SAME code twice. 

<font color="purple">For example, if you made a car class. You could use the class to create a new object, such as a mustang. </font>
