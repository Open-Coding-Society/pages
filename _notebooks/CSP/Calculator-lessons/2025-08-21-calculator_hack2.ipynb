# %% [raw]
# ---
# layout: post
# categories: [Calculator Lessons]
# title: Calculator Lesson - Hack 2
# description: Directions for hack 2 of the calculator lesson (100% hack).
# permalink: /_notebooks/CSP/Calculator-lessons/2025-08-21-calculator_hack2
# ---

# %% [markdown]
# ## Goal 🎯
# Add a **calculation history** feature like [Google Chrome's calculator](https://www.google.com/search?q=calculator) that shows recent expressions and their results.
#
# ### What You'll Learn
# By completing this hack, you'll practice:
# - **Variables**: Storing calculation history data
# - **Functions**: Creating reusable code to manage history
# - **DOM Manipulation**: Updating the webpage display
# - **Arrays**: Managing lists of calculations
# - **Event Handling**: Responding to user interactions
#
# ---
#
# ## Hack Summary 📝
#
# ### What You're Building
# You'll add a **history panel** to the calculator that:
# - Saves every calculation you make
# - Displays them in a list format: `expression = result`
# - Shows the most recent calculation at the top
# - Updates automatically after each calculation
#
# ### How It Works
# 1. **Storage**: Use an array to store calculation history
# 2. **Recording**: When user clicks "=" button, save the expression and result
# 3. **Display**: Show the history list in a dedicated HTML section
# 4. **Integration**: Connect your history functions to the existing calculator code
#
# ### Your Task Overview
# You'll complete 6 TODO items that guide you through:
# - Creating variables to store history data (TODO-H1)
# - Writing functions to add and display history (TODO-H2, H3)
# - Connecting these functions to the calculator's existing code (TODO-H4-H6)
#
# ---
#
# ## What You Need to Edit 📂
# ### File Location
# Open `hacks/hack2-calculator.md` and find the `<script>` section with TODO comments (TODO-H1 through TODO-H6)
#
# ---
#
# ## Getting Started 🚀
#
# ### Step 1: Run the Starter Code
# 1. Start the local server by running `make` in your terminal
# 2. Open the hack page in your browser: http://127.0.0.1:4500/Calculator-Lesson/hack2calculator
# 3. Test the basic calculator - it should work for simple calculations
#
# ### Step 2: Understand the Current Code
# Before you start coding, take a moment to explore:
# - Try some calculations (like `5 + 3`, `12 * 4`)
# - Notice there's no history feature yet
# - Look at the calculator layout and buttons
# - Open `hacks/hack2-calculator.md` to see the code you'll be editing
#
# ---
#
# ## Requirements & Examples 📋
#
# ### Requirement 1: Show Recent History
# **Goal**: Display the most recent calculations
# **Example**: After calculating `5 + 3` and `12 * 4`, the history should show:
# 12 * 4 = 48
# 5 + 3 = 8
#
# ### Requirement 2: Correct Format
# **Goal**: Each entry should follow the format: `expression = result`
# **Examples**:
# - Simple: `7 + 2 = 9`
# - With decimals: `10 / 3 = 3.333333333333333`
# - Complex: `5 + 3 * 2 = 11`
#
# ### Requirement 3: Handle All Operations
# **Goal**: Work with addition (+), subtraction (-), multiplication (*), and division (/)
# **Examples to test**:
# - `15 - 7 = 8`
# - `3.5 * 2 = 7`
# - `100 / 4 = 25`
#
# ---
# ## Turn in 📤
# Submit the link to your github page with the finished code.
#
# [Google Form](https://forms.gle/Bn2PfeYUEhBruacK6)
