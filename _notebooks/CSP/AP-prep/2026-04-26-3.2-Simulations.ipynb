# %% [raw]
# ---
# layout: post
# title: Simulations
# description: This page will teach you about Simulations in programming.
# permalink: /csp/AP-prep/simulations/p4/
# breadcrumb: True
# Author: Ethan Patel, Aneesh Deevi, Samarth Vaka
# ---

# %% [markdown]
# ## Simulations
#
# ---
