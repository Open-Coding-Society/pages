# %% [markdown]
# ---
# layout: post
# courses: { csp: {week: 4} }
# title: Crowdsourcing Lesson
# description: This page will teach you about crowdsourcing.
# permalink: /csp/crowdsourcing
# Author: ShareCoder
# ---

# %% [markdown]
# ## Crowdsourcing
#
# ---
#
# ### What is Crowdsourcing?
# Crowdsourcing is when many people use the internet to contribute data, ideas, or work to solve a problem.
#
# Key idea: **many small contributions → one large solution**
#
# - Uses **distributed individuals** (people in different locations)
# - Relies on **widespread access to data and the internet**
# - Allows **problem-solving at scale**
#
# ---
#
# ### Citizen Science (Important Concept)
# Citizen science is when everyday people help with scientific research by collecting and sharing data.
#
# - Uses **distributed individuals(people in different locations contributing data)**
# - People use their own devices (phones, computers)
# - Data is combined to solve real-world problems
#
# Examples:
# - Tracking animals
# - Measuring air quality
#
# ---
#
# ### Examples of Crowdsourcing
#
# - **Wikipedia** → users build knowledge together
# - **reCAPTCHA** → users help train AI
# - **Reviews (Yelp, Amazon)** → users share opinions
# - **OpenStreetMap** → people build maps
#
# ---
#
# ### Why Crowdsourcing Works
# Computing allows collaboration that would otherwise be impossible:
#
# - **Scale** → thousands or millions of contributors
# - **Speed** → instant data sharing
# - **Diversity** → many perspectives
# - **Efficiency** → automated data processing
#
# ---
#
# ### Risks and Unintended Consequences
# Crowdsourcing is powerful, but not perfect:
#
# - Data can be incorrect or biased
# - Some users act in bad faith
# - Hard to verify information
# - Privacy concerns
#
# ---
#
# ### Why Computing is Essential
# Crowdsourcing only works because of computing systems:
#
# - Collect data from many users
# - Store large datasets
# - Process and analyze information
# - Share results globally
#
# ---
#
# ## KEY AP CSP VOCABULARY
#
# | Term | Definition |
# |------|-----------|
# | **Crowdsourcing** | Obtaining input or data from a large number of people via the internet |
# | **Citizen Science** | Scientific research conducted by distributed individuals contributing data |
# | **Problem-Solving at Scale** | Using many people to solve problems efficiently |
# | **Unintended Consequences** | Unexpected positive or negative outcomes of a computing innovation |
#
# ---

# %% [markdown]
# ### **EXAMPLE System**

# %%
crowd_ratings = []


def add_user_rating(score):
    crowd_ratings.append(score)


def get_average_rating():
    if len(crowd_ratings) == 0:
        return 0
    return sum(crowd_ratings) / len(crowd_ratings)


# simulate multiple users contributing ratings
add_user_rating(5)
add_user_rating(4)
add_user_rating(2)
add_user_rating(5)
add_user_rating(3)


print("Number of contributors:", len(crowd_ratings))
print("Average rating:", get_average_rating())

# %% [markdown]
# ### **Explanation (Crowdsourcing Connection)**
#
# - **Input:** Many users each submit a rating (crowd contribution)
# - **Processing:** The program combines all ratings to calculate an average
# - **Output:** The final average is displayed
#
# ### **Key Idea:**
# This demonstrates **crowdsourcing**, where many individuals contribute data, and the computer combines it to produce a result. This shows **problem-solving at scale**.

# %% [markdown]
# ## **MCQ**

# %% [markdown]
# <div style="
#   width: 600px;
#   margin: 40px auto;
#   padding: 25px;
#   border: 2px solid black;
#   border-radius: 10px;
#   background-color: white;
#   text-align: center;
#   font-family: Arial;
#   color: black;
# ">
#
#   <h3 id="question" style="color:black;">Loading question...</h3>
#   <div id="answers"></div>
#   <p id="score" style="color:black;"></p>
#   <button id="nextBtn" onclick="nextQuestion()" style="
#     display:none;
#     margin-top: 10px;
#     padding: 8px 16px;
#     border: 1px solid black;
#     background-color: white;
#     cursor: pointer;
#   ">
#     Next
#   </button>
#
# </div>
#
#
# <script>
# const questions = [
#   {
#     q: "A navigation app collects location and speed data from thousands of drivers to suggest faster routes. Which concept does this best demonstrate?",
#     choices: [
#       "A single expert solving a problem",
#       "Obtaining input from many people via the internet",
#       "Storing data privately",
#       "Running a program offline"
#     ],
#     answer: 1
#   },
#   {
#     q: "An online platform asks thousands of users to label images to improve an AI system. How does this demonstrate problem-solving at scale?",
#     choices: [
#       "By limiting participation to experts",
#       "By using many contributors to complete small tasks",
#       "By reducing the need for data",
#       "By avoiding the use of computing"
#     ],
#     answer: 1
#   },
#   {
#     q: "Volunteers use a mobile app to record local air quality data, which scientists later analyze. This is an example of:",
#     choices: [
#       "A company hiring engineers",
#       "Citizen science using distributed individuals",
#       "A teacher grading assignments",
#       "A private lab experiment"
#     ],
#     answer: 1
#   },
#   {
#     q: "A website collects product reviews from thousands of users. What is one advantage of this approach?",
#     choices: [
#       "All data is guaranteed to be correct",
#       "Fast and large-scale data collection",
#       "Bias is completely eliminated",
#       "No computing is required"
#     ],
#     answer: 1
#   },
#   {
#     q: "A review platform allows anyone to post ratings, but some users submit false reviews. What is a likely unintended consequence?",
#     choices: [
#       "Improved collaboration",
#       "Spread of incorrect or biased data",
#       "Faster data processing",
#       "Lower system costs"
#     ],
#     answer: 1
#   },
#   {
#     q: "Why are computing systems essential for crowdsourcing platforms that collect data from many users?",
#     choices: [
#       "They limit communication between users",
#       "They allow large numbers of people to contribute and share data",
#       "They remove the need for human input",
#       "They guarantee all data is accurate"
#     ],
#     answer: 1
#   }
# ];
#
#
# let current = 0;
# let score = 0;
# let answered = false;
#
#
# function loadQuestion() {
#   answered = false;
#   document.getElementById("nextBtn").style.display = "none";
#
#   const q = questions[current];
#   document.getElementById("question").innerText = q.q;
#
#   const answersDiv = document.getElementById("answers");
#   answersDiv.innerHTML = "";
#
#   q.choices.forEach((choice, index) => {
#     const btn = document.createElement("button");
#     btn.innerText = choice;
#
#     btn.style.display = "block";
#     btn.style.margin = "8px auto";
#     btn.style.padding = "10px";
#     btn.style.width = "90%";
#     btn.style.border = "1px solid black";
#     btn.style.backgroundColor = "white";
#     btn.style.color = "black";
#     btn.style.cursor = "pointer";
#
#     btn.onclick = () => checkAnswer(btn, index);
#     answersDiv.appendChild(btn);
#   });
# }
#
#
# function checkAnswer(button, index) {
#   if (answered) return;
#   answered = true;
#
#   const correct = questions[current].answer;
#   const buttons = document.querySelectorAll("#answers button");
#
#   buttons.forEach((btn, i) => {
#     if (i === correct) {
#       btn.style.backgroundColor = "#c8f7c5";
#     } else if (i === index) {
#       btn.style.backgroundColor = "#f7c5c5";
#     }
#     btn.disabled = true;
#   });
#
#   if (index === correct) {
#     score++;
#   }
#
#   document.getElementById("score").innerText =
#     "Score: " + score + "/" + questions.length;
#
#   document.getElementById("nextBtn").style.display = "block";
# }
#
#
# function nextQuestion() {
#   current++;
#   if (current < questions.length) {
#     loadQuestion();
#   } else {
#     document.getElementById("question").innerText = "Finished";
#     document.getElementById("answers").innerHTML = "";
#
#     document.getElementById("score").innerText =
#       "Final Score: " + score + "/" + questions.length;
#
#     document.getElementById("nextBtn").style.display = "none";
#   }
# }
#
#
# loadQuestion();
# </script>
