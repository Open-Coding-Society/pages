# %% [raw]
# ---
# layout: post
# title: Sprint 9 - CSP Objectives (Final)
# description: CSP final project.  This includes help system, plans, code, testing, and N@tM.
# type: issues
# courses: { csp: {week: 34} }
# comments: true
# permalink: /csp/sprint9/objectives
# ---

# %% [markdown]
# ## Final Project
#
# This Final Project serves as a culmination of your learning in Computer Science Principles, JavaScript, Python, GitHub Pages frontend, and Flask backend. By building a project, you will apply programming fundamentals and explore the impacts of computing through a topic of personal and social relevance, such as Pilot City or Open Coding Society.
#
# You will demonstrate your skills in:
#
# - **Software Engineering Practices:** Planning changes, using checklists, tracking progress (burndowns), writing commented code, and building help documentation
# - **Software Development Lifecycle Practices:** Source control, forking, branching, building, testing and verification, pull requests, and merging/integrating
# - **Retrospective Engineering Practices:** Presentations, live reviews, demos, code reviews, and revising plans
# - **Data Types:** Numbers, strings, booleans, arrays, JSON objects, and SQLite tables
# - **Operators:** String operations, mathematical operations, and boolean expressions
# - **Control Structures:** Iteration, conditions, nested conditions, try/except, and .then/.catch
# - **Input/Output:** HTML5 input, validation, and working with the Document Object Model (DOM)
# - **Procedures and Functions:** Writing procedures/functions, creating parameters, calling procedures, and handling return values
# - **Lists and Collections:** Creating lists, managing data with lists, using lists to handle complexity
# - **Deployment Practices:** DNS, Docker, docker-compose, and nginx
#
# This project is your opportunity to showcase your growth as a developer and your ability to apply computer science principles to real-world problems.
#
# ## AP CSP Create Performance Task & PPR Requirements
#
# ### Personalized Project Reference (PPR) Overview
#
# The PPR is a **required document** for the AP Computer Science Principles Create Performance Task. It contains specific code excerpts that you will reference when answering four written response questions during the AP Exam on **May 12-16, 2026**.
#
# **Critical Deadline:** PPR must be submitted as "Final" in your AP Digital Portfolio by **April 30, 2026, 11:59 p.m. ET**
#
# ### Required PPR Code Segments
#
# You must submit the following code segments as clear screenshots to the AP Digital Portfolio:
#
# | PPR Component | Evidence Required | Technical Requirements |
# |---------------|-------------------|------------------------|
# | **Procedure/Function** | Screenshot of a student-developed procedure that implements an algorithm | • Must have at least one explicit parameter<br>• Must include sequencing, selection (if-statements), and iteration (loops)<br>• Must be meaningfully used in your program |
# | **Procedure Call** | Screenshot showing where your program calls that procedure | • Must show the actual invocation with argument(s) passed<br>• Must be from your working program code |
# | **List Creation** | Screenshot showing a list being created or populated | • Must store multiple values of the same type<br>• Can be array, list, dictionary, or other collection<br>• Must show initialization or data being added |
# | **List Use** | Screenshot showing how that same list is used to manage complexity | • Must demonstrate list being accessed/manipulated<br>• Must show how list simplifies program logic<br>• Example: iterating through list, accessing elements, updating values |
#
# ### PPR Formatting & Submission Rules
#
# **Critical Rules (Failure to follow may result in lost points or unscorable submission):**
#
# ✅ **DO:**
# - Use clear screenshots with at least 10-point font size
# - Ensure code is readable and properly formatted
# - Keep screenshots focused on relevant code segments
# - Submit by April 30, 2026, 11:59 p.m. ET deadline
#
# ❌ **DO NOT:**
# - Include any code comments in your PPR screenshots
# - Include your name or any personally identifying information
# - Use blurry or low-quality screenshots
# - Include unnecessary code outside the required segments
#
# ### Technical Standards Checklist
#
# To score full points on the exam questions, ensure your code meets these standards:
#
# **Procedure Requirements:**
# - ✅ Has at least one explicit parameter (not just empty parentheses)
# - ✅ Contains sequencing (multiple lines of code executed in order)
# - ✅ Contains selection (if/else statements or conditional logic)
# - ✅ Contains iteration (for loop, while loop, or forEach)
# - ✅ Returns a value or produces a meaningful side effect
#
# **List Requirements:**
# - ✅ Stores multiple values (not just a single variable)
# - ✅ Is accessed using an index or key
# - ✅ Manages complexity (simplifies program compared to not using a list)
# - ✅ Is meaningfully used (not just for display purposes)
#
# **Example of Managing Complexity with Lists:**
# - **Without List:** Would need separate variables (score1, score2, score3...) and repetitive code
# - **With List:** Single list structure (`scores = []`) with loop to process all values efficiently
#
# ### Sprint 9 Project Requirements Aligned to PPR
#
# | Requirement | Purpose | Deadline |
# |-------------|---------|----------|
# | Identify PPR code segments in your project | Ensure you have qualifying procedure and list | Week 34 |
# | Prepare clean screenshots (no comments) | Meet PPR formatting requirements | Week 35 |
# | Submit PPR to AP Digital Portfolio | Make PPR available for AP Exam | April 30, 2026 |
# | Complete project v2.0 with documented PPR | Demonstrate competency in blog | Finals Week |

# %% [markdown]
# ## Project Planning
#
# ### CSP Course Timeline
#
# **Sprints 7-8 (Weeks 25-33): Data Structures 1 (DS1) & Project Development**
# - Learn foundational data structures (lists, dictionaries, procedures with algorithms)
# - Build initial project prototype focused on PPR-qualifying code
# - Peer collaboration on project features
# - Identify and refine PPR code segments (procedure + list)
#
# **Sprint 9 (Weeks 34-36): PPR Submission & Project v2.0**
# - Finalize PPR code segments and screenshots (no comments)
# - Submit PPR to AP Digital Portfolio by April 30, 2026
# - Refine project v2.0 with enhanced features and documentation
# - Final showcase at N@tM
#
# ### Sprint 9 Project Requirements
#
# During Sprint 9, you will:
# - **Finalize PPR Submission**: Prepare and submit all four required code segments (procedure, procedure call, list creation, list use) by April 30, 2026
# - Create **Issues** to describe your project plans, including who is assigned, expected goals, and stretch goals
# - Build a **Help** system in your blog to guide future engineers (use search system, give yourself credit as author)
# - Develop Individual **Blog** to document:
#   - PPR code segments with explanations (with comments for blog context)
#   - Design documents showing data flow and algorithm logic
#   - PR and commit history highlighting your contributions
# - Create a **LinkedIn page** and feature your capstone project
#
# ### Sprint 9 Checkpoints
#
# Development milestones:
# - **PPR Preparation (Week 34)**: Identify qualifying procedure and list, ensure technical requirements met
# - **Testing (Week 35)**: Implement unit tests, validate functionality, test edge cases
# - **Data backup/restore (Week 35)**: Implement database backup and restore features
# - **UI workflow improvements (Week 35-36)**: Refine user experience and interface design
# - **PPR Submission (by April 30)**: Submit final PPR screenshots to AP Digital Portfolio
# - Set and achieve at least one milestone each checkpoint, continuing the iterative cycle of development

# %% [markdown]
# ## Final Deliverables & Blog
#
# Throughout Sprint 9, you will update your personal blog to document your project v2.0, PPR preparation, and implementation details. Your blog will serve as the central point for communication with your instructor and preparation for the AP Exam.
#
# **Blog Requirements:**
# - **PPR Documentation**: Feature your PPR code segments with detailed explanations
#   - Show procedure with algorithm (sequencing, selection, iteration)
#   - Explain how your list manages complexity
#   - Include annotated versions (WITH comments for educational purposes in blog)
# - **Design Documents**: Show data structures, algorithms, and program flow
# - **Code Highlights**: Explain key programming concepts and decisions
# - **Testing Documentation**: Show test cases, validation, and debugging process
# - **Contribution Evidence**: PR and commit history showing individual work
#
# **Important Note on PPR vs. Blog:**
# - **PPR Submission**: NO comments, clean code screenshots only (submitted to AP Digital Portfolio)
# - **Blog Documentation**: WITH comments and explanations (for learning and instructor communication)
#
# **Key Events:**
# - **April 30, 2026 (11:59 p.m. ET)**: PPR submission deadline to AP Digital Portfolio
# - **Finals Week -1 (Week 35)**
#   - **Monday:** Demo your project and PPR code to the instructor
#   - **Thursday:** N@tM (Night at the Museum) showcase at 6pm
# - **Finals Week (Week 36)**
#   - **Monday:** Present LinkedIn page, Blog portfolio, and Analytics
#   - **Final Day:** Instructor completes final grading
# - **May 12-16, 2026**: AP CSP Exam (you will reference your PPR during written responses)
#
# **AP Exam Preparation:**
# Your PPR will be available to you during the AP Exam. You will answer four written response questions about:
# 1. Your procedure's purpose and functionality
# 2. How your procedure implements an algorithm with sequencing, selection, and iteration
# 3. How you use a list to manage complexity in your program
# 4. The overall purpose and functionality of your program
